# %%
import pandas as pd
import pytz
import datetime as dt
import math
import seaborn as sns
import matplotlib as mpl
#mpl.rcParams['path.simplify'] = False
import matplotlib.pyplot as plt
import numpy as np

# %%
def read_manipulate_psychopy(psychopy_path):
    
    psychopy_df = pd.read_csv(psychopy_path)
    col_list = [col for col in psychopy_df.columns if col.endswith('_ts')]
    col_list.insert(0, "Reference_time")
    psychopy_df_selected = psychopy_df[col_list]
    
    return psychopy_df_selected


def get_nonNan_list_psychopy(psychopy_df, col_name):
    
    
    selected_vals=[val for val in psychopy_df[col_name].to_list() if not(math.isnan(val))]
    
    return selected_vals


def get_offset_timestamp(timestamp, offset_mins):
    
    time_zone = 'Europe/Berlin'
    tz = pytz.timezone(time_zone)
    local_time = dt.datetime.fromtimestamp(timestamp, tz)
    time_change = dt.timedelta(minutes=offset_mins)
    new_time = local_time + time_change
    new_timestamp =  dt.datetime.timestamp(new_time)
    return new_timestamp


def read_shimmer_sensor(sensor_file_path):
    
    shimmer_df = pd.read_csv(sensor_file_path, sep='\t', low_memory=False)
    shimmer_df = shimmer_df.reset_index()
    shimmer_df.columns = shimmer_df.iloc[0]
    shimmer_df.drop([0, 1], axis=0, inplace=True)
    shimmer_df=shimmer_df.reset_index(drop=True)
    
    return shimmer_df

# %%
psychopy_path = "/home/muhammad/Desktop/Datasets/data_sony_digiRelax/study/VP004_081123/Psychopy_data/VP004_081123_DigiRelax_Experiment_2023-11-08_10h28.36.317.csv"
hr_shimmer_file_path =  "/home/muhammad/Desktop/Datasets/data_sony_digiRelax/study/VP004_081123/Shimmer_data/2023-11-08_09.49.11_VP004_081123_SD_Session1/VP004_081123_Session1_Shimmer_6B1E_Calibrated_SD.csv"
skin_shimmer_file_path = "/home/muhammad/Desktop/Datasets/data_sony_digiRelax/study/VP004_081123/Shimmer_data/2023-11-08_09.49.11_VP004_081123_SD_Session1/VP004_081123_Session1_Shimmer_893E_Calibrated_SD.csv"

# %%
psychopy_df = read_manipulate_psychopy(psychopy_path)

# %%
psychopy_df
# Out:
#     Reference_time  baseline_instruction_ts  end_countDown_3min_ts  \
# 0     1.699436e+09             1.699436e+09           1.699436e+09
# 1              NaN                      NaN                    NaN
# 2              NaN                      NaN                    NaN
# 3              NaN                      NaN                    NaN
# 4              NaN                      NaN                    NaN
# 5              NaN                      NaN                    NaN
# 6              NaN                      NaN                    NaN
# 7              NaN                      NaN                    NaN
# 8              NaN                      NaN                    NaN
# 9              NaN                      NaN                    NaN
# 10             NaN                      NaN                    NaN
# 11             NaN                      NaN                    NaN
# 12             NaN                      NaN                    NaN
# 13             NaN                      NaN                    NaN
# 14             NaN                      NaN                    NaN
# 15             NaN                      NaN                    NaN
# 16             NaN                      NaN                    NaN
# 17             NaN                      NaN                    NaN
# 18             NaN                      NaN                    NaN
# 19             NaN                      NaN                    NaN
# 20             NaN                      NaN                    NaN
#
#         sam_e_ts      sam_a_ts  saliva_probe_1_ts  change_room_ts  \
# 0            NaN           NaN                NaN             NaN
# 1   1.699436e+09           NaN                NaN             NaN
# 2            NaN  1.699436e+09                NaN             NaN
# 3            NaN           NaN       1.699436e+09             NaN
# 4            NaN           NaN                NaN    1.699436e+09
# 5            NaN           NaN                NaN             NaN
# 6            NaN           NaN                NaN             NaN
# 7   1.699437e+09           NaN                NaN             NaN
# 8            NaN  1.699437e+09                NaN             NaN
# 9            NaN           NaN                NaN             NaN
# 10           NaN           NaN                NaN             NaN
# 11           NaN           NaN                NaN             NaN
# 12  1.699439e+09           NaN                NaN             NaN
# 13           NaN  1.699439e+09                NaN             NaN
# 14           NaN           NaN                NaN             NaN
# 15           NaN           NaN                NaN             NaN
# 16           NaN           NaN                NaN             NaN
# 17  1.699440e+09           NaN                NaN             NaN
# 18           NaN  1.699440e+09                NaN             NaN
# 19           NaN           NaN                NaN             NaN
# 20           NaN           NaN                NaN             NaN
#
#     tsst_prep_ts  end_countDown_5min_prep_ts  tsst_pres_ts  \
# 0            NaN                         NaN           NaN
# 1            NaN                         NaN           NaN
# 2            NaN                         NaN           NaN
# 3            NaN                         NaN           NaN
# 4   1.699436e+09                1.699437e+09           NaN
# 5            NaN                         NaN  1.699437e+09
# 6            NaN                         NaN           NaN
# 7            NaN                         NaN           NaN
# 8            NaN                         NaN           NaN
# 9            NaN                         NaN           NaN
# 10           NaN                         NaN           NaN
# 11           NaN                         NaN           NaN
# 12           NaN                         NaN           NaN
# 13           NaN                         NaN           NaN
# 14           NaN                         NaN           NaN
# 15           NaN                         NaN           NaN
# 16           NaN                         NaN           NaN
# 17           NaN                         NaN           NaN
# 18           NaN                         NaN           NaN
# 19           NaN                         NaN           NaN
# 20           NaN                         NaN           NaN
#
#     end_countDown_5min_pres_ts  end_countDown_5min_arithmetic_ts  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# 5                 1.699437e+09                               NaN
# 6                          NaN                      1.699437e+09
# 7                          NaN                               NaN
# 8                          NaN                               NaN
# 9                          NaN                               NaN
# 10                         NaN                               NaN
# 11                         NaN                               NaN
# 12                         NaN                               NaN
# 13                         NaN                               NaN
# 14                         NaN                               NaN
# 15                         NaN                               NaN
# 16                         NaN                               NaN
# 17                         NaN                               NaN
# 18                         NaN                               NaN
# 19                         NaN                               NaN
# 20                         NaN                               NaN
#
#     tsst_end_exp_ts  saliva_probe_2_ts  relaxation_prep_ts  relaxation_ts  \
# 0               NaN                NaN                 NaN            NaN
# 1               NaN                NaN                 NaN            NaN
# 2               NaN                NaN                 NaN            NaN
# 3               NaN                NaN                 NaN            NaN
# 4               NaN                NaN                 NaN            NaN
# 5               NaN                NaN                 NaN            NaN
# 6               NaN                NaN                 NaN            NaN
# 7      1.699437e+09                NaN                 NaN            NaN
# 8               NaN                NaN                 NaN            NaN
# 9               NaN       1.699437e+09                 NaN            NaN
# 10              NaN                NaN        1.699438e+09            NaN
# 11              NaN                NaN                 NaN   1.699439e+09
# 12              NaN                NaN                 NaN            NaN
# 13              NaN                NaN                 NaN            NaN
# 14              NaN                NaN                 NaN            NaN
# 15              NaN                NaN                 NaN            NaN
# 16              NaN                NaN                 NaN            NaN
# 17              NaN                NaN                 NaN            NaN
# 18              NaN                NaN                 NaN            NaN
# 19              NaN                NaN                 NaN            NaN
# 20              NaN                NaN                 NaN            NaN
#
#     saliva_probe_3_ts  limeSurvey_ts  saliva_probe_4_ts
# 0                 NaN            NaN                NaN
# 1                 NaN            NaN                NaN
# 2                 NaN            NaN                NaN
# 3                 NaN            NaN                NaN
# 4                 NaN            NaN                NaN
# 5                 NaN            NaN                NaN
# 6                 NaN            NaN                NaN
# 7                 NaN            NaN                NaN
# 8                 NaN            NaN                NaN
# 9                 NaN            NaN                NaN
# 10                NaN            NaN                NaN
# 11                NaN            NaN                NaN
# 12                NaN            NaN                NaN
# 13                NaN            NaN                NaN
# 14       1.699439e+09            NaN                NaN
# 15                NaN   1.699440e+09                NaN
# 16                NaN            NaN                NaN
# 17                NaN            NaN                NaN
# 18                NaN            NaN                NaN
# 19                NaN            NaN       1.699440e+09
# 20                NaN            NaN                NaN

# %%
##

# %%
timestamp_sensor_col_name = "Shimmer_893E_Timestamp_Unix_CAL"
data_col_name = "Shimmer_893E_GSR_Skin_Conductance_CAL"

# %%
shimmer_df=read_shimmer_sensor(skin_shimmer_file_path)

# %%
shimmer_df_selected = shimmer_df[[timestamp_sensor_col_name, data_col_name]]

# %%
shimmer_df_selected
# Out:
# 0       Shimmer_893E_Timestamp_Unix_CAL Shimmer_893E_GSR_Skin_Conductance_CAL
# 0                  1.699435616039795E12                     8.401217356441235
# 1                 1.6994356160476074E12                     8.401217356441235
# 2                 1.6994356160515137E12                     8.401217356441235
# 3                   1.69943561605542E12                     8.401217356441235
# 4                 1.6994356160593262E12                     8.401217356441235
# ...                                 ...                                   ...
# 1071480           1.6994398024890137E12                     5.557044581434826
# 1071481             1.69943980249292E12                     5.557044581434826
# 1071482           1.6994398024968262E12                     5.562149813020893
# 1071483           1.6994398025007324E12                     5.562149813020893
# 1071484           1.6994398025046387E12                     5.562149813020893
#
# [1071485 rows x 2 columns]

# %%
event_interest_list_new = ["sam_e_ts", "tsst_prep_ts", "tsst_end_exp_ts", "saliva_probe_3_ts"]
offset_min_list_new = [[-4], [5], [-5, -10], [-20, -15, -10, -5]]

# %%
mean_cumm_list = []
std_cumm_list  = []
event_interets_plot = []


##---outer loop to hnadle muultiple offsets from the selected events 
for ind, event_selected in enumerate(event_interest_list_new):
    
    offset_list_selected_event = offset_min_list_new[ind]
    
    print(event_selected)
    
    current_event_timestamp = get_nonNan_list_psychopy(psychopy_df, event_selected)[0]
    
    offset_min_list_selected = offset_min_list_new[ind]
    
    for offset_min in offset_min_list_selected:
        
        #print(ofset)
        print("current_event_timestamp:" + str(current_event_timestamp))
        
        event_plot = event_selected +" "+ str(offset_min) + " min"
        
        print(event_plot)
        
        timestamp_offset = get_offset_timestamp(current_event_timestamp, offset_min)
        
        print("offset_timestamp:" + str (timestamp_offset))
        
        current_event_timestamp = timestamp_offset
# Out:
# sam_e_ts
# current_event_timestamp:1699435992.4043405
# sam_e_ts -4 min
# offset_timestamp:1699435752.404341
# tsst_prep_ts
# current_event_timestamp:1699436255.517251
# tsst_prep_ts 5 min
# offset_timestamp:1699436555.517251
# tsst_end_exp_ts
# current_event_timestamp:1699437244.9046574
# tsst_end_exp_ts -5 min
# offset_timestamp:1699436944.904657
# current_event_timestamp:1699436944.904657
# tsst_end_exp_ts -10 min
# offset_timestamp:1699436344.904657
# saliva_probe_3_ts
# current_event_timestamp:1699438756.1618104
# saliva_probe_3_ts -20 min
# offset_timestamp:1699437556.16181
# current_event_timestamp:1699437556.16181
# saliva_probe_3_ts -15 min
# offset_timestamp:1699436656.16181
# current_event_timestamp:1699436656.16181
# saliva_probe_3_ts -10 min
# offset_timestamp:1699436056.16181
# current_event_timestamp:1699436056.16181
# saliva_probe_3_ts -5 min
# offset_timestamp:1699435756.16181

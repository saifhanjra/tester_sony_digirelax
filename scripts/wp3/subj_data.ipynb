# %%
import pandas as pd

# %%
data_path = "/home/muhammad/Desktop/Datasets/data_sony_digiRelax/subjective_data/subjective_data.xlsx"

# %%
data=pd.read_excel(data_path)

# %%
data
# Out:
#          subject       date    condition dominant_hand session_start  \
# 0   VP004_081123 2023-11-08     2D_scent             r      10:08:00
# 1   VP005_081123 2023-11-08     2D_scent             r      13:57:00
# 2   VP006_091123 2023-11-09     VR_scent             r      09:57:00
# 3   VP007_091123 2023-11-09     VR_scent             r      14:04:00
# 4   VP008_101123 2023-11-10  VR_no_scent             r      10:04:00
# 5   VP009_101123 2023-11-10  VR_no_scent             r      14:02:00
# 6   VP010_131123 2023-11-13     VR_scent             r      09:33:00
# 7   VP011_131123 2023-11-13     VR_scent             r      14:25:00
# 8   VP012_141123 2023-11-14  2D_no_scent             r      09:32:00
# 9   VP013_151123 2023-11-15  VR_no_scent             r      09:31:00
# 10  VP014_151123 2023-11-15  VR_no_scent             l      14:04:00
# 11  VP015_161123 2023-11-16  2D_no_scent             r      09:28:00
# 12  VP016_161123 2023-11-16  2D_no_scent             r      14:30:00
# ...

# %%
data["subject"].to_list()
# Out:
# ['VP004_081123',
#  'VP005_081123',
#  'VP006_091123',
#  'VP007_091123',
#  'VP008_101123',
#  'VP009_101123',
#  'VP010_131123',
#  'VP011_131123',
#  'VP012_141123',
#  'VP013_151123',
#  'VP014_151123',
#  'VP015_161123',
#  'VP016_161123',
#  'VP017_171123',
#  'VP018_201123',
#  'VP019_201123',
#  'VP020_221123',
#  'VP021_221123',
#  'VP022_231123',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
data["condition"]
# Out:
# 0        2D_scent
# 1        2D_scent
# 2        VR_scent
# 3        VR_scent
# 4     VR_no_scent
# 5     VR_no_scent
# 6        VR_scent
# 7        VR_scent
# 8     2D_no_scent
# 9     VR_no_scent
# 10    VR_no_scent
# 11    2D_no_scent
# 12    2D_no_scent
# 13       VR_scent
# 14    VR_no_scent
# 15    VR_no_scent
# 16    VR_no_scent
# 17    VR_no_scent
# 18       2D_scent
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# Name: condition, dtype: object

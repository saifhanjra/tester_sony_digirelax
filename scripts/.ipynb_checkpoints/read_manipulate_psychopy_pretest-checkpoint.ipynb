# %%
import pandas as pd
import pytz
import datetime as dt
import math
import seaborn as sns

# %%
time_zone = 'Europe/Berlin'
tz = pytz.timezone(time_zone)

# %%
psychopy_file_path = "/home/muhammad/Desktop/Datasets/data_sony_digiRelax/pilot_study/VP001_251023/Psychopy_data/VP001_251023_DigiRelax_Experiment_2023-10-25_09h16.01.523.csv"
skin_shimmer_file_path =  "/home/muhammad/Desktop/Datasets/data_sony_digiRelax/pilot_study/VP001_251023/Shimmer_data/2023-10-25_07.34.27_VP001_251023_SD_Session1/VP001_251023_Session1_Shimmer_FBA7_Calibrated_SD.csv"

# %%
def read_manipulate_psychopy(psychopy_path):
    
    psychopy_df = pd.read_csv(psychopy_path)
    col_list = [col for col in psychopy_df.columns if col.endswith('_ts')]
    col_list.insert(0, "Reference_time")
    psychopy_df_selected = psychopy_df[col_list]
    
    return psychopy_df_selected    


def read_shimmer_sensor(sensor_file_path):
    
    shimmer_df = pd.read_csv(sensor_file_path, sep='\t', low_memory=False)
    shimmer_df = shimmer_df.reset_index()
    shimmer_df.columns = shimmer_df.iloc[0]
    shimmer_df.drop([0, 1], axis=0, inplace=True)
    shimmer_df=shimmer_df.reset_index(drop=True)

    
    return shimmer_df

# %%
psychopy_df_selected = read_manipulate_psychopy(psychopy_file_path)

# %%
psychopy_df_selected
# Out:
#    Reference_time      sam_e_ts      sam_a_ts  saliva_probe_1_ts  \
# 0    1.698218e+09  1.698218e+09           NaN                NaN
# 1             NaN           NaN  1.698218e+09                NaN
# 2             NaN  1.698220e+09           NaN       1.698219e+09
# 3             NaN           NaN  1.698220e+09                NaN
# 4             NaN  1.698221e+09           NaN                NaN
# 5             NaN           NaN  1.698221e+09                NaN
# 6             NaN           NaN           NaN                NaN
# 7             NaN  1.698222e+09           NaN                NaN
# 8             NaN           NaN  1.698222e+09                NaN
# 9             NaN           NaN           NaN                NaN
#
#    change_room_ts  tsst_prep_ts   tsst_end_ts  tsst_end_exp_ts  \
# 0             NaN           NaN           NaN              NaN
# 1             NaN           NaN           NaN              NaN
# 2    1.698219e+09  1.698219e+09  1.698220e+09     1.698220e+09
# 3             NaN           NaN           NaN              NaN
# 4             NaN           NaN           NaN              NaN
# 5             NaN           NaN           NaN              NaN
# 6             NaN           NaN           NaN              NaN
# 7             NaN           NaN           NaN              NaN
# 8             NaN           NaN           NaN              NaN
# 9             NaN           NaN           NaN              NaN
#
#    saliva_probe_2_ts  saliva_probe_3_ts  saliva_probe_4_ts  \
# 0                NaN                NaN                NaN
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3                NaN                NaN                NaN
# 4       1.698220e+09                NaN                NaN
# 5                NaN                NaN                NaN
# 6                NaN       1.698221e+09                NaN
# 7                NaN                NaN                NaN
# 8                NaN                NaN                NaN
# 9                NaN                NaN       1.698222e+09
#
#    final_instruction_ts
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9          1.698222e+09

# %%
shimmer_df = read_shimmer_sensor(skin_shimmer_file_path)

# %%
shimmer_df
# Out:
# 0       Shimmer_FBA7_Timestamp_Unix_CAL Shimmer_FBA7_Accel_LN_X_CAL  \
# 0                 1.6982179802870789E12         -2.4216867469879517
# 1                 1.6982179802948914E12         -2.4216867469879517
# 2                 1.6982179802987976E12          -2.397590361445783
# 3                 1.6982179803027039E12           -2.36144578313253
# 4                   1.69821798030661E12         -2.3734939759036147
# ...                                 ...                         ...
# 1079534             1.69822219824411E12         -0.5421686746987953
# 1079535           1.6982221982480164E12         -0.5301204819277109
# 1079536           1.6982221982519226E12         -0.5421686746987953
# 1079537           1.6982221982558289E12         -0.5301204819277109
# 1079538            1.698222198259735E12         -0.5542168674698795
#
# 0       Shimmer_FBA7_Accel_LN_Y_CAL Shimmer_FBA7_Accel_LN_Z_CAL  \
# 0                  9.46987951807229         -0.8674698795180723
# 1                 9.457831325301205         -0.8915662650602411
# 2                 9.457831325301205         -0.8674698795180723
# 3                 9.421686746987952         -0.8433734939759037
# 4                 9.409638554216867         -0.8795180722891567
# ...                             ...                         ...
# 1079534           9.072289156626507           3.662650602409639
# 1079535           9.072289156626507          3.6506024096385543
# 1079536           9.072289156626507          3.6385542168674703
# 1079537           9.060240963855422          3.6144578313253013
# 1079538           9.060240963855422          3.6385542168674703
#
# 0       Shimmer_FBA7_GSR_Range_CAL Shimmer_FBA7_GSR_Skin_Conductance_CAL  \
# 0                              0.0                     6.724618664917171
# 1                              0.0                     6.724618664917171
# 2                              0.0                     6.724618664917171
# 3                              0.0                     6.724618664917171
# 4                              0.0                     6.724618664917171
# ...                            ...                                   ...
# 1079534                        1.0                     12.70436880192978
# 1079535                        1.0                    12.709474033515848
# 1079536                        1.0                    12.709474033515848
# 1079537                        1.0                    12.714579265101914
# 1079538                        1.0                    12.714579265101914
#
# 0       Shimmer_FBA7_GSR_Skin_Resistance_CAL  NaN
# 0                         148.70731707317077  NaN
# 1                         148.70731707317077  NaN
# 2                         148.70731707317077  NaN
# 3                         148.70731707317077  NaN
# 4                         148.70731707317077  NaN
# ...                                      ...  ...
# 1079534                    78.71308016877636  NaN
# 1079535                    78.68146214099215  NaN
# 1079536                    78.68146214099215  NaN
# 1079537                    78.64986950411563  NaN
# 1079538                    78.64986950411563  NaN
#
# [1079539 rows x 8 columns]

# %%
shimmer_df
# Out:
# 0       Shimmer_FBA7_Timestamp_Unix_CAL Shimmer_FBA7_Accel_LN_X_CAL  \
# 0                 1.6982179802870789E12         -2.4216867469879517
# 1                 1.6982179802948914E12         -2.4216867469879517
# 2                 1.6982179802987976E12          -2.397590361445783
# 3                 1.6982179803027039E12           -2.36144578313253
# 4                   1.69821798030661E12         -2.3734939759036147
# ...                                 ...                         ...
# 1079534             1.69822219824411E12         -0.5421686746987953
# 1079535           1.6982221982480164E12         -0.5301204819277109
# 1079536           1.6982221982519226E12         -0.5421686746987953
# 1079537           1.6982221982558289E12         -0.5301204819277109
# 1079538            1.698222198259735E12         -0.5542168674698795
#
# 0       Shimmer_FBA7_Accel_LN_Y_CAL Shimmer_FBA7_Accel_LN_Z_CAL  \
# 0                  9.46987951807229         -0.8674698795180723
# 1                 9.457831325301205         -0.8915662650602411
# 2                 9.457831325301205         -0.8674698795180723
# 3                 9.421686746987952         -0.8433734939759037
# 4                 9.409638554216867         -0.8795180722891567
# ...                             ...                         ...
# 1079534           9.072289156626507           3.662650602409639
# 1079535           9.072289156626507          3.6506024096385543
# 1079536           9.072289156626507          3.6385542168674703
# 1079537           9.060240963855422          3.6144578313253013
# 1079538           9.060240963855422          3.6385542168674703
#
# 0       Shimmer_FBA7_GSR_Range_CAL Shimmer_FBA7_GSR_Skin_Conductance_CAL  \
# 0                              0.0                     6.724618664917171
# 1                              0.0                     6.724618664917171
# 2                              0.0                     6.724618664917171
# 3                              0.0                     6.724618664917171
# 4                              0.0                     6.724618664917171
# ...                            ...                                   ...
# 1079534                        1.0                     12.70436880192978
# 1079535                        1.0                    12.709474033515848
# 1079536                        1.0                    12.709474033515848
# 1079537                        1.0                    12.714579265101914
# 1079538                        1.0                    12.714579265101914
#
# 0       Shimmer_FBA7_GSR_Skin_Resistance_CAL  NaN
# 0                         148.70731707317077  NaN
# 1                         148.70731707317077  NaN
# 2                         148.70731707317077  NaN
# 3                         148.70731707317077  NaN
# 4                         148.70731707317077  NaN
# ...                                      ...  ...
# 1079534                    78.71308016877636  NaN
# 1079535                    78.68146214099215  NaN
# 1079536                    78.68146214099215  NaN
# 1079537                    78.64986950411563  NaN
# 1079538                    78.64986950411563  NaN
#
# [1079539 rows x 8 columns]

# %%
# system imports
import os
import sys

# data science
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import seaborn as sns

# signal processing
from scipy import signal
from scipy.ndimage import label
from scipy.stats import zscore
from scipy.interpolate import interp1d
from scipy.integrate import trapz


# misc
import warnings

import glob

##
import pytz
import datetime as dt
import math
import seaborn as sns

#import pickle

# %%
csv_files_path_hrv = "/home/muhammad/Desktop/repos_ixp/tester_sony_digirelax/scripts/wp4/ecg_eda_complete_analysis/ecg_analysis/ecg_timedomain_analysis"

# %%
hrv_files_list = glob.glob(csv_files_path_hrv+ "/*.csv")
hrv_files_list = sorted(hrv_files_list)

# %%
col_interest = "mean_bpm"
event_interest = "event_interst"

cumm_data_all_subs = []

# %%
for sel_file in hrv_files_list:
    fol_path, file_name_ii=os.path.split(sel_file)
    sub_id_ii = file_name_ii[0:5]
    #print(sub_id_ii)
    df_ii = pd.read_csv(sel_file)
    mean_bpm_ii = list(df_ii[col_interest].values)
    mean_bpm_ii.insert(0, sub_id_ii)
    event_interest_ii = list(df_ii[event_interest].values)
    
    #print(event_interest_ii)
    #print(mean_bpm_ii)
    cumm_data_all_subs.append(mean_bpm_ii)
    
    #print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
    #hr_data_dict = from_rr_to_time_anal(sel_file)    
    #csv_time_domain_feat_filename = file_name_ii + ".csv"
    #dest_path_csv = os.path.join(dest_path,csv_time_domain_feat_filename)
    #print(dest_path_csv)
    #df_export = pd.DataFrame.from_dict(hr_data_dict)
    #df_export.to_csv(dest_path_csv)

event_interest_ii.insert(0, "subject_id")
#df = pd.DataFrame()
df = pd.DataFrame(data=cumm_data_all_subs, columns= event_interest_ii)

# %%
# Out:
#    subject_id  baseline_instruction_ts 3 min  tsst_prep_ts 5 min  \
# 0       VP004                      57.957259           59.373724
# 1       VP005                      66.252168           93.613818
# 2       VP006                      94.110434           99.338096
# 3       VP007                      48.867319           55.503263
# 4       VP008                      64.969054           74.181307
# ..        ...                            ...                 ...
# 75      VP081                      77.448290           83.905358
# 76      VP083                      84.978651          134.551188
# 77      VP084                      55.030657           69.095513
# 78      VP085                      59.127763           67.176978
# 79      VP086                      73.430355           83.822967
#
#     tsst_pres_ts 5 min  tsst_pres_ts 10 min  relaxation_prep_ts 5 min  \
# 0            59.491681            65.044295                 55.202792
# 1           117.997358            97.250134                 61.644901
# 2           107.357074            99.265964                 87.335453
# 3            60.335698            63.551259                 48.251594
# 4            75.607062            69.030642                 63.235403
# ..                 ...                  ...                       ...
# 75           95.915526            90.976758                 75.364185
# 76          142.647404           138.851402                 90.782471
# 77           84.458799            84.912160                 54.624721
# 78           64.461447            66.550831                 56.286668
# 79           94.323645            93.946228                 76.590673
#
#     relaxation_prep_ts 10 min  relaxation_prep_ts 15 min  \
# 0                   53.558058                  51.899117
# 1                   59.526624                  60.775076
# 2                   87.243446                  88.785206
# 3                   49.914431                  49.822993
# 4                   65.045281                  62.321699
# ..                        ...                        ...
# 75                  75.087313                  74.596711
# 76                  90.343391                  87.521613
# 77                  58.357952                  57.111164
# 78                  57.692119                  58.355316
# 79                  74.756521                  72.960539
#
#     -2.5 min saliva_probe_3_ts 2.5 min  saliva_probe_4_ts -5 min
# 0                            55.541916                 75.879077
# 1                            66.364733                 71.453559
# 2                            90.188988                 89.585203
# 3                            52.119334                 52.879400
# 4                            68.719240                 70.639484
# ..                                 ...                       ...
# 75                           81.471145                 80.475769
# 76                           93.365032                 92.133163
# 77                           61.790055                 62.372821
# 78                           59.432991                 63.877060
# 79                           83.167463                 88.457150
#
# [80 rows x 10 columns]

# %%
df = pd.DataFrame()

# %%
df= pd.read_csv("/home/muhammad/Desktop/repos_ixp/tester_sony_digirelax/scripts/wp4/ecg_eda_complete_analysis/ecg_analysis/ecg_timedomain_analysis/VP004_081123_DigiRelax_Experiment_2023-11-08_10h28.36.317.csv")

# %%
df
# Out:
#    Unnamed: 0                                         subject_id  \
# 0           0  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
# 1           1  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
# 2           2  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
# 3           3  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
# 4           4  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
# 5           5  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
# 6           6  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
# 7           7  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
# 8           8  VP004_081123_DigiRelax_Experiment_2023-11-08_1...
#
#                         event_interst   mean_bpm    std_bpm     mean_ibi  \
# 0       baseline_instruction_ts 3 min  57.957259   2.289199  1036.859557
# 1                  tsst_prep_ts 5 min  59.373724   5.232373  1017.351974
# 2                  tsst_pres_ts 5 min  59.491681   4.552757  1014.300847
# 3                 tsst_pres_ts 10 min  65.044295   3.581554   925.195312
# 4            relaxation_prep_ts 5 min  55.202792   3.374632  1090.827441
# 5           relaxation_prep_ts 10 min  53.558058   2.571980  1122.834738
# 6           relaxation_prep_ts 15 min  51.899117   3.624524  1161.636353
# 7  -2.5 min saliva_probe_3_ts 2.5 min  55.541916   4.969553  1089.142628
# 8            saliva_probe_4_ts -5 min  75.879077  26.384552   874.983587
#
#       std_ibi  norm_mean_ibi  norm_std_ibi  norm_mean_bpm  norm_std_bpm
# 0   40.904404       0.601615      0.038783       0.155425      0.021207
# 1   79.528341       0.583119      0.075405       0.168547      0.048472
# 2   75.425454       0.580226      0.071515       0.169640      0.042176
# 3   50.015256       0.495741      0.047422       0.221079      0.033179
# 4   64.407801       0.652785      0.061068       0.129908      0.031262
# 5   53.299867       0.683132      0.050536       0.114672      0.023826
# 6   79.646832       0.719922      0.075517       0.099304      0.033577
# 7   99.704708       0.651187      0.094535       0.133050      0.046037
# 8  257.749700       0.448133      0.244385       0.321450      0.244422

# %%
df = pd.read_csv("/home/muhammad/Desktop/repos_ixp/tester_sony_digirelax/scripts/wp4/ecg_eda_complete_analysis/ecg_analysis/ecg_freq_domain_features/VP005_081123_DigiRelax_Experiment_2023-11-08_14h17.35.226.csv")

# %%
df
# Out:
#    Unnamed: 0                                         subject_id  \
# 0           0  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
# 1           1  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
# 2           2  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
# 3           3  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
# 4           4  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
# 5           5  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
# 6           6  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
# 7           7  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
# 8           8  VP005_081123_DigiRelax_Experiment_2023-11-08_1...
#
#                         event_interst    vlf_power     lf_power     hf_power  \
# 0       baseline_instruction_ts 3 min   168.054769  1000.013813  4930.540544
# 1                  tsst_prep_ts 5 min   206.860721   405.676836   327.967851
# 2                  tsst_pres_ts 5 min   173.323600   448.126597   168.686675
# 3                 tsst_pres_ts 10 min   377.977255   724.648389   495.872123
# 4            relaxation_prep_ts 5 min   248.749992   647.282702  3530.899354
# 5           relaxation_prep_ts 10 min   143.173145   500.009791  2538.551303
# 6           relaxation_prep_ts 15 min   336.136080   333.474037  2869.806943
# 7  -2.5 min saliva_probe_3_ts 2.5 min  1455.497610   791.036476  1814.688068
# 8            saliva_probe_4_ts -5 min   195.320456   477.459691  1088.670212
#
#    total_power
# 0  6098.609127
# 1   940.505407
# 2   790.136872
# 3  1598.497767
# 4  4426.932047
# 5  3181.734239
# 6  3539.417060
# 7  4061.222154
# 8  1761.450359

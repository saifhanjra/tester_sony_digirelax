# %%
# system imports
import os
import sys

# data science
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import seaborn as sns

# signal processing
from scipy import signal
from scipy.ndimage import label
from scipy.stats import zscore
from scipy.interpolate import interp1d
from scipy.integrate import trapz


# misc
import warnings

import glob

##
import pytz
import datetime as dt
import math
import seaborn as sns

#import pickle

# %%
csv_files_path_hrv = "/home/muhammad/Desktop/repos_ixp/tester_sony_digirelax/scripts/wp4/ecg_eda_complete_analysis/ecg_analysis/ecg_timedomain_analysis"

# %%
hrv_files_list = glob.glob(csv_files_path_hrv+ "/*.csv")
hrv_files_list = sorted(hrv_files_list)

# %%
col_interest = "mean_bpm"
event_interest = "event_interst"

cumm_data_all_subs = []

# %%
for sel_file in hrv_files_list:
    fol_path, file_name_ii=os.path.split(sel_file)
    sub_id_ii = file_name_ii[0:5]
    #print(sub_id_ii)
    df_ii = pd.read_csv(sel_file)
    mean_bpm_ii = list(df_ii[col_interest].values)
    mean_bpm_ii.insert(0, sub_id_ii)
    event_interest_ii = list(df_ii[event_interest].values)
    
    #print(event_interest_ii)
    #print(mean_bpm_ii)
    cumm_data_all_subs.append(mean_bpm_ii)
    
    #print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
    #hr_data_dict = from_rr_to_time_anal(sel_file)    
    #csv_time_domain_feat_filename = file_name_ii + ".csv"
    #dest_path_csv = os.path.join(dest_path,csv_time_domain_feat_filename)
    #print(dest_path_csv)
    #df_export = pd.DataFrame.from_dict(hr_data_dict)
    #df_export.to_csv(dest_path_csv)

event_interest_ii.insert(0, "subject_id")
df = pd.DataFrame()

df = pd.DataFrame(cumm_data_all_subs, columns= event_interest_ii)

# %%
df
# Out:
#    subject_id  baseline_instruction_ts 3 min  tsst_prep_ts 5 min  \
# 0       VP004                      57.957259           59.373724
# 1       VP005                      66.252168           93.613818
# 2       VP006                      94.110434           99.338096
# 3       VP007                      48.867319           55.503263
# 4       VP008                      64.969054           74.181307
# ..        ...                            ...                 ...
# 75      VP081                      77.448290           83.905358
# 76      VP083                      84.978651          134.551188
# 77      VP084                      55.030657           69.095513
# 78      VP085                      59.127763           67.176978
# 79      VP086                      73.430355           83.822967
#
#     tsst_pres_ts 5 min  tsst_pres_ts 10 min  relaxation_prep_ts 5 min  \
# 0            59.491681            65.044295                 55.202792
# 1           117.997358            97.250134                 61.644901
# 2           107.357074            99.265964                 87.335453
# 3            60.335698            63.551259                 48.251594
# 4            75.607062            69.030642                 63.235403
# ..                 ...                  ...                       ...
# 75           95.915526            90.976758                 75.364185
# 76          142.647404           138.851402                 90.782471
# 77           84.458799            84.912160                 54.624721
# 78           64.461447            66.550831                 56.286668
# 79           94.323645            93.946228                 76.590673
#
#     relaxation_prep_ts 10 min  relaxation_prep_ts 15 min  \
# 0                   53.558058                  51.899117
# 1                   59.526624                  60.775076
# 2                   87.243446                  88.785206
# 3                   49.914431                  49.822993
# 4                   65.045281                  62.321699
# ..                        ...                        ...
# 75                  75.087313                  74.596711
# 76                  90.343391                  87.521613
# 77                  58.357952                  57.111164
# 78                  57.692119                  58.355316
# 79                  74.756521                  72.960539
#
#     -2.5 min saliva_probe_3_ts 2.5 min  saliva_probe_4_ts -5 min
# 0                            55.541916                 75.879077
# 1                            66.364733                 71.453559
# 2                            90.188988                 89.585203
# 3                            52.119334                 52.879400
# 4                            68.719240                 70.639484
# ..                                 ...                       ...
# 75                           81.471145                 80.475769
# 76                           93.365032                 92.133163
# 77                           61.790055                 62.372821
# 78                           59.432991                 63.877060
# 79                           83.167463                 88.457150
#
# [80 rows x 10 columns]

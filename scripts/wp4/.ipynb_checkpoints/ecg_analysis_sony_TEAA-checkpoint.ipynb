# %%
#system imports
import os
import sys

# data science
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import seaborn as sns

# signal processing
from scipy import signal
from scipy.ndimage import label
from scipy.stats import zscore
from scipy.interpolate import interp1d
from scipy.integrate import trapz


# misc
import warnings

import glob

##
import pytz
import datetime as dt
import math
import seaborn as sns


import pickle

# %%
import biosppy
from biosppy import storage
from biosppy.signals import ecg


# misc
import warnings

#signal processing
from scipy import signal
from scipy.ndimage import label
from scipy.stats import zscore
from scipy.interpolate import interp1d
from scipy.integrate import trapz

time_zone = 'Europe/Berlin'
tz = pytz.timezone(time_zone)

# %% [markdown]
# ## Read and manipulate Psychopy dataframe

# %%
def read_manipulate_psychopy(psychopy_path):
    
    psychopy_df = pd.read_csv(psychopy_path)
    col_list = [col for col in psychopy_df.columns if col.endswith('_ts')]
    #col_list.insert(0, "Reference_time")
    psychopy_df_selected = psychopy_df[col_list]
    
    return psychopy_df_selected


def get_nonNan_list_psychopy(psychopy_df, col_name):
    
    
    selected_vals=[val for val in psychopy_df[col_name].to_list() if not(math.isnan(val))]
    
    return selected_vals


def sel_pre_analysis_file(events_path_list):
    
    for sel_event_path in events_path_list:
        fol_path, file_name_ii=os.path.split(sel_event_path)
        if "trigger" in file_name_ii:
            events_with_trigger= sel_event_path
            
            
    return sel_event_path

# %% [markdown]
# # Handling delays in the file

# %%
def from_excel_val_to_timestamp(ts_val):
    

    
    ##########
    ts_val = str(ts_val)
    ts_val = str(ts_val.replace('.',''))
    ts_val= ts_val[0:10] + '.' + ts_val[10:]
    ts_val = float(ts_val)
    return ts_val

def rreplace(string: str, find: str, replace: str, n_occurences: int) -> str:
    """
    Given a `string`, `find` and `replace` the first `n_occurences`
    found from the right of the string.
    """
    temp = string.rsplit(find, n_occurences)
    return replace.join(temp)

def get_offset_timestamp(timestamp, offset_mins):
    
    time_zone = 'Europe/Berlin'
    tz = pytz.timezone(time_zone)
    local_time = dt.datetime.fromtimestamp(timestamp, tz)
    time_change = dt.timedelta(minutes=offset_mins)
    new_time = local_time + time_change
    new_timestamp =  dt.datetime.timestamp(new_time)
    return new_timestamp

def from_excel_val_to_mins(excel_mins):
    
    offset_mins=str(excel_mins)
    offset_mins=rreplace(string= offset_mins, find=".", replace="", n_occurences=offset_mins.count(".")-1)
    offset_mins = float(offset_mins)
    
    return offset_mins



def get_delayed_psychopy_timestamp(timestamp, offset_mins):
    
    time_zone = 'Europe/Berlin'
    tz = pytz.timezone(time_zone)
    local_time = dt.datetime.fromtimestamp(timestamp, tz)
    time_change = dt.timedelta(minutes=offset_mins)
    new_time = local_time - time_change
    new_timestamp =  dt.datetime.timestamp(new_time)
    return new_timestamp

# %% [markdown]
# ## Read, manipulate and slice Shimmer dataframe

# %%
#######---------------------------------------------------
###### ------------------Shimmer--------------------------
###----------------------------------------------------------


def read_shimmer_sensor(sensor_file_path):
    
    shimmer_df = pd.read_csv(sensor_file_path, sep='\t', low_memory=False)
    shimmer_df = shimmer_df.reset_index()
    shimmer_df.columns = shimmer_df.iloc[0]
    shimmer_df.drop([0, 1], axis=0, inplace=True)
    shimmer_df=shimmer_df.reset_index(drop=True)
    
    return shimmer_df

def standardize_timestamps_shimmer(shimmer_df, timestamps_col_name):
    
    timesstamps_list = shimmer_df[timestamps_col_name].to_list()
    new_timestamps_list = [float(val)/1000 for val in  timesstamps_list]
    
    shimmer_df[timestamps_col_name] = new_timestamps_list
    
    return shimmer_df



def get_offset_timestamp(timestamp, offset_mins):
    
    time_zone = 'Europe/Berlin'
    tz = pytz.timezone(time_zone)
    local_time = dt.datetime.fromtimestamp(timestamp, tz)
    time_change = dt.timedelta(minutes=offset_mins)
    new_time = local_time + time_change
    new_timestamp =  dt.datetime.timestamp(new_time)
    return new_timestamp

def get_list_timestamp_interest(starting_timestamp, list_offset_mins):
    
    starting_timestamp_list=[]
    
    for offset_min in list_offset_mins:
        starting_timestamp_list.append(starting_timestamp)
        timestamp_offset = get_offset_timestamp(starting_timestamp, offset_min)
        starting_timestamp = timestamp_offset  
     
    
    #starting_timestamp_list = sorted(starting_timestamp_list, key = lambda x:float(x))
    return starting_timestamp_list
        
        

def slice_df_wrt_timestamps(df, start_timestamp, end_timestamp, timestamps_col):
    
    sliced_df=df[(df[timestamps_col]>= start_timestamp) & (df[timestamps_col] <= end_timestamp)]
    
    return sliced_df


def from_str_to_float(str_list):
    #float(recovery_onset_str_timestamps[0][1:-1])
    
    float_array =[float(val[1:-1]) for val in str_list]
    
    return float_array

def col_from_str_float (df, col_name):
    
    str_list = df[col_name].values
    
    float_array =[float(val) for val in str_list]
    
    df[col_name] = float_array
    
    return df

# %% [markdown]
# ## Time Domain HRV

# %%
def detect_peaks(ecg_signal, threshold=0.3, qrs_filter=None):
    '''
    Peak detection algorithm using cross corrrelation and threshold 
    '''
    if qrs_filter is None:
        # create default qrs filter, which is just a part of the sine function
        t = np.linspace(1.5 * np.pi, 3.5 * np.pi, 15)
        qrs_filter = np.sin(t)
    
    # normalize data
    ecg_signal = (ecg_signal - ecg_signal.mean()) / ecg_signal.std()

    # calculate cross correlation
    similarity = np.correlate(ecg_signal, qrs_filter, mode="same")
    similarity = similarity / np.max(similarity)

    # return peaks (values in ms) using threshold
    return ecg_signal[similarity > threshold].index, similarity



def group_peaks(p, threshold=5):
    '''
    The peak detection algorithm finds multiple peaks for each QRS complex. 
    Here we group collections of peaks that are very near (within threshold) and we take the median index 
    '''
    # initialize output
    output = np.empty(0)

    # label groups of sample that belong to the same peak
    peak_groups, num_groups = label(np.diff(p) < threshold)

    # iterate through groups and take the mean as peak index
    for i in np.unique(peak_groups)[1:]:
        peak_group = p[np.where(peak_groups == i)]
        output = np.append(output, int(np.median(peak_group)))
        
        
    #output = int(output)
    return output

def from_rr_ind_2_msec(r_peaks_ind, sampling_freq = 256):
    
    # RR-intervals are the differences between successive peaks
    r_peaks_sec = r_peaks_ind*1/sampling_freq
    r_peaks_msec = r_peaks_sec*1000

    r_peaks_diff_msec=np.diff(r_peaks_msec)
    
    return r_peaks_diff_msec
    
    
    
    
    

def remove_outliers_rri(r_peaks_diff_msec, sampling_freq = 256, outlier_std = 1.5):
    
    # RR-intervals are the differences between successive peaks
    #r_peaks_sec = r_peaks*1/sampling_freq
    #r_peaks_msec = r_peaks_sec*1000

    #r_peaks_diff=np.diff(r_peaks_msec)
    
    rr_corrected = r_peaks_diff_msec.copy()

    rr_corrected[np.abs(zscore(r_peaks_diff_msec)) > outlier_std] = np.median(r_peaks_diff_msec)
    
    return rr_corrected
    


def get_plot_ranges(start=10, end=20, n=5):
    '''
    Make an iterator that divides into n or n+1 ranges. 
    - if end-start is divisible by steps, return n ranges
    - if end-start is not divisible by steps, return n+1 ranges, where the last range is smaller and ends at n
    
    # Example:
    >> list(get_plot_ranges())
    >> [(0.0, 3.0), (3.0, 6.0), (6.0, 9.0)]

    '''
    distance = end - start
    for i in np.arange(start, end, np.floor(distance/n)):
        yield (int(i), int(np.minimum(end, np.floor(distance/n) + i)))
        
        
        
def timedomain(rr):
    results = {}

    hr = 60000/rr
    
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)
    #results['Mean HR (Kubios\' style) (beats/min)'] = 60000/np.mean(rr)
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)
    return results

# %% [markdown]
# ## Plot raw and filtered ECG

# %%
def plot_ecg_wf(sliced_ecg_df,r_peaks, time_offset, dest_fol_path, fig_name,  raw_data_col_name="ecg", 
                filtered_data_col_name="filtered", nr_plots=3, 
                fig_title_raw = "Raw ECG", fig_title_filtered = "Filtered ECG"):    
    
    
    starting_index_slcide_df= sliced_ecg_df.index[0]
    sampfrom = starting_index_slcide_df
    sampto = starting_index_slcide_df+256*time_offset*60
    
    rr_interval_cumm = []
    for start, stop in get_plot_ranges(sampfrom, sampto, nr_plots):
        print(start)
        print(stop)
        
        # get sliced data of ECG
        #cond_slice = (sliced_ecg_df.index>= start) & (sliced_ecg_df.index <= stop)
        #sliced_ecg_hrv =sliced_ecg_df.filtered[cond_slice]
        
        sliced_ecg_hrv = sliced_ecg_df[filtered_data_col_name][(sliced_ecg_df.index >= start) & (sliced_ecg_df.index<= stop)]
        
        sliced_ecg_raw = sliced_ecg_df[raw_data_col_name][(sliced_ecg_df.index >= start) & (sliced_ecg_df.index<= stop)]
        
        
        r_peaks_selected = [r_p for r_p in r_peaks if r_p >= start and r_p <= stop]
        
        fig_ecg=plt.figure(figsize=(20, 15))

        plt.subplot(211)
        plt.title(fig_title_raw)
        plt.plot(sliced_ecg_raw, label="ECG", color="#51A6D8", linewidth=1)
        #plt.plot(sliced_ecg_hrv.index[start: stop], sliced_ecg_hrv, label="ECG", color="#51A6D8", linewidth=1)
        #plt.plot(r_peaks_selected, np.repeat(0.3, len(r_peaks_selected)), label="peaks", color="orange", marker="o", linestyle="None")
        plt.legend(loc="upper right")
        plt.xlabel("Time (milliseconds)")
        plt.ylabel("Amplitude (arbitrary unit)")

        plt.subplot(212)
        plt.title(fig_title_filtered)
        
        #plt.plot(ecg_slice.index, similarity, label="Similarity with QRS filter", color="olive", linewidth=1)
        plt.plot(sliced_ecg_hrv, label="Filtered ECG", color="olive", linewidth=1)
        plt.plot(r_peaks_selected, np.repeat(0.2, len(r_peaks_selected)), label="peaks", color="orange", marker="o", linestyle="None")
        plt.legend(loc="upper right")
        plt.xlabel("Time (milliseconds)")
        plt.ylabel("Similarity (normalized)")
        
        plt.show()
        plot_figure = []
        plot_figure = fig_name
        print(plot_figure)
        #print(plot_figure[0])
        fig_name = str(start) + "_" + str(stop) + "_" + plot_figure
        fig_path = os.path.join(dest_fol_path, fig_name)
        fig_ecg.savefig(fig_path)

# %% [markdown]
# ### Plot mean and standard deviations

# %%
def plot_mean_std(mean_list, std_list, label_list, title_figure, y_label_fig):
    x_pos = np.arange(len(label_list))
    fig, ax = plt.subplots()
    ax.bar(x_pos, mean_list, yerr=std_list, align='center', alpha=0.5, capsize=10 )
    ax.set_ylabel(y_label_fig)
    ax.set_xticks(x_pos)
    ax.set_xticklabels(label_list, rotation=45, ha='right', rotation_mode='anchor')
    #title_ax = "VP001_251023_Session1_Shimmer_FBA7_Calibrated_SD"
    ax.set_title(title_figure)
    ax.yaxis.grid(True)
    #plt.ylim(0, 1) 
    plt.tight_layout()
    plt.show()
    return fig

# %% [markdown]
# ## Min-Max Normaliaztion

# %%
def min_max_norm(all_rr_one_list, all_rr_sublist):
    
    mean_norm_list =[]
    std_norm_list = []
    
    all_rr_one_list = np.array(all_rr_one_list)
    max_val = np.max(all_rr_one_list)
    min_val =np.min(all_rr_one_list)
    
    for sel_list in all_rr_sublist:
        
        sel_list_np = np.array(sel_list)
        
        range_list = max_val-min_val
        
        sel_lis_np_sub = sel_list_np - min_val
        
        sel_lis_norm= sel_lis_np_sub/range_list
        
        mean_norm = np.mean(sel_lis_norm)
        mean_norm_list.append(mean_norm)
        
        std_norm  = np.std(sel_lis_norm)   
        std_norm_list.append(std_norm)
        #print(mean_norm)
        #print(std_norm)
                
        
    return mean_norm_list, std_norm_list

# %%
def timedomain(rr):
    results = {}

    hr = 60000/rr
    
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)
    #results['Mean HR (Kubios\' style) (beats/min)'] = 60000/np.mean(rr)
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)
    return results

# %% [markdown]
# ## Single File

# %%
path_psychopy_events_file = "D:/Datasets/Dataset_Sony_TEAA/Psychopy_Events/psychopy_events_WP2_P14_WHVF.csv"
#psy_events_df = pd.read_csv(path_psychopy_events_file, index_col="Unnamed: 0")
psychopy_event_dir="D:/Datasets/Dataset_Sony_TEAA/Psychopy_Events"
psychopy_events_files = glob.glob(psychopy_event_dir+ "/*.csv")

for sel_event_file in psychopy_events_files:
    
    fol_path, file_name_ii=os.path.split(sel_event_file)
    
    print(file_name_ii)


    try:
        psy_events_df = pd.read_csv(sel_event_file, sep=";", index_col="Unnamed: 0")
    except:
        psy_events_df = pd.read_csv(sel_event_file, index_col="Unnamed: 0")
        
        
    pa_row=psy_events_df.loc["pa"]
    b1_row=psy_events_df.loc["b1"]
    b2_row=psy_events_df.loc["b2"]
    b1_type=psy_events_df.loc["b1_type"]["block_type"]
    b2_type=psy_events_df.loc["b2_type"]["block_type"]
    
    baseline_onset_pa=pa_row["baseline_onset(unix)"]
    baseline_onset_pa=from_excel_val_to_timestamp(baseline_onset_pa)
    baseline_onset_b1=b1_row["baseline_onset(unix)"]
    baseline_onset_b1=from_excel_val_to_timestamp(baseline_onset_b1)
    baseline_onset_b2=b2_row["baseline_onset"]
    baseline_onset_b2=from_excel_val_to_timestamp(baseline_onset_b2)

    baseline_onset_timestamps = []
    baseline_onset_timestamps.append(baseline_onset_pa)
    baseline_onset_timestamps.append(baseline_onset_b1)
    baseline_onset_timestamps.append(baseline_onset_b2)

    task_onset_pa = pa_row["task_onset(unix)"]
    task_onset_pa=from_excel_val_to_timestamp(task_onset_pa)
    task_onset_b1=b1_row["task_onset(unix)"]
    task_onset_b1=from_excel_val_to_timestamp(task_onset_b1)
    task_onset_b2 = b2_row["task_onset(unix)"]
    task_onset_b2=from_excel_val_to_timestamp(task_onset_b2)

    task_onset_float_timestamp = []
    task_onset_float_timestamp.append(task_onset_pa)
    task_onset_float_timestamp.append(task_onset_b1)
    task_onset_float_timestamp.append(task_onset_b2)

    recovery_onset_pa = pa_row["recovery_onset(unix)"]
    recovery_onset_pa=from_excel_val_to_timestamp(recovery_onset_pa)
    recovery_onset_b1=b1_row["recovery_onset(unix)"]
    recovery_onset_b1=from_excel_val_to_timestamp(recovery_onset_b1)
    recovery_onset_b2 = b2_row["recovery_onset(unix)"]
    recovery_onset_b2=from_excel_val_to_timestamp(recovery_onset_b2)

    recovery_onset_list_timestamps = []
    recovery_onset_list_timestamps.append(recovery_onset_pa)
    recovery_onset_list_timestamps.append(recovery_onset_b1)
    recovery_onset_list_timestamps.append(recovery_onset_b2)
    
    
    delay_mins= from_excel_val_to_mins(pa_row["offset"])
    print("Delay for this recording sesssion is: " + str(delay_mins)+ " mins")
    print("----------------------------------")
    
    for ind_ii, sel_baseline in enumerate(baseline_onset_timestamps):
    
        baseline_ts = sel_baseline
        baseline_ts = get_delayed_psychopy_timestamp(baseline_ts, delay_mins)

        baseline_time = dt.datetime.fromtimestamp(baseline_ts, tz)
        print("baseline start time: "+str(baseline_time))
        ##------------------------------------------
        task_ts = task_onset_float_timestamp[ind_ii]
        task_ts = get_delayed_psychopy_timestamp(task_ts, delay_mins)

        task_time = dt.datetime.fromtimestamp(task_ts, tz)
        print("task time: "+str(task_time))
        recovery_ts = recovery_onset_list_timestamps[ind_ii]
        recovery_ts = get_delayed_psychopy_timestamp(recovery_ts, delay_mins)
        recovery_time = dt.datetime.fromtimestamp(recovery_ts, tz)

        print("recovery time: "+str(recovery_time))

        print("---------------------------------------------")
# Out:
# psychopy_events_WP2_P01_FQPD.csv
# Delay for this recording sesssion is: 42.8808236122131 mins
# ----------------------------------
# baseline start time: 2023-02-08 10:20:19.278423+01:00
# task time: 2023-02-08 10:25:19.865453+01:00
# recovery time: 2023-02-08 10:30:20.875583+01:00
# ---------------------------------------------
# baseline start time: 2023-02-08 10:36:17.065243+01:00
# task time: 2023-02-08 10:41:17.770433+01:00
# recovery time: 2023-02-08 10:46:21.162253+01:00
# ---------------------------------------------
# baseline start time: 2023-02-08 10:58:45.713393+01:00
# task time: 2023-02-08 11:03:42.115363+01:00
# recovery time: 2023-02-08 11:08:45.423663+01:00
# ---------------------------------------------
# psychopy_events_WP2_P02_YPCK.csv
# Delay for this recording sesssion is: 4.03904175758361 mins
# ----------------------------------
# baseline start time: 2023-02-08 13:11:20.627585+01:00
# task time: 2023-02-08 13:16:21.217975+01:00
# recovery time: 2023-02-08 13:21:22.232895+01:00
# ---------------------------------------------
# baseline start time: 2023-02-08 13:27:16.566395+01:00
# task time: 2023-02-08 13:32:17.264115+01:00
# recovery time: 2023-02-08 13:37:20.141175+01:00
# ---------------------------------------------
# baseline start time: 2023-02-08 13:49:43.550755+01:00
# task time: 2023-02-08 13:54:40.210665+01:00
# recovery time: 2023-02-08 13:59:42.091475+01:00
# ---------------------------------------------
# psychopy_events_WP2_P03_RFIB.csv
# Delay for this recording sesssion is: 4.15123152732849 mins
# ----------------------------------
# baseline start time: 2023-02-08 15:39:36.932258+01:00
# task time: 2023-02-08 15:44:37.547968+01:00
# recovery time: 2023-02-08 15:49:38.563258+01:00
# ---------------------------------------------
# baseline start time: 2023-02-08 15:55:15.799258+01:00
# task time: 2023-02-08 16:00:16.389818+01:00
# recovery time: 2023-02-08 16:05:19.119298+01:00
# ---------------------------------------------
# baseline start time: 2023-02-08 16:17:35.299708+01:00
# task time: 2023-02-08 16:22:31.796048+01:00
# recovery time: 2023-02-08 16:27:34.530928+01:00
# ---------------------------------------------
# psychopy_events_WP2_P04_TUYR.csv
# Delay for this recording sesssion is: 41.8369364738464 mins
# ----------------------------------
# baseline start time: 2023-02-09 09:39:29.393622+01:00
# task time: 2023-02-09 09:44:29.994522+01:00
# recovery time: 2023-02-09 09:49:31.004312+01:00
# ---------------------------------------------
# baseline start time: 2023-02-09 09:55:54.101742+01:00
# task time: 2023-02-09 10:00:54.727702+01:00
# recovery time: 2023-02-09 10:05:56.492352+01:00
# ---------------------------------------------
# baseline start time: 2023-02-09 10:19:05.232102+01:00
# task time: 2023-02-09 10:24:01.690402+01:00
# recovery time: 2023-02-09 10:29:03.453982+01:00
# ---------------------------------------------
# psychopy_events_WP2_P05_MCUW.csv
# Delay for this recording sesssion is: 50.0261163711547 mins
# ----------------------------------
# baseline start time: 2023-02-09 15:15:18.159718+01:00
# task time: 2023-02-09 15:20:18.704428+01:00
# recovery time: 2023-02-09 15:25:19.719738+01:00
# ---------------------------------------------
# baseline start time: 2023-02-09 15:31:16.507678+01:00
# task time: 2023-02-09 15:36:17.065158+01:00
# recovery time: 2023-02-09 15:41:20.556628+01:00
# ---------------------------------------------
# baseline start time: 2023-02-09 15:53:55.981098+01:00
# task time: 2023-02-09 15:58:51.580058+01:00
# recovery time: 2023-02-09 16:03:54.240708+01:00
# ---------------------------------------------
# psychopy_events_WP2_P06_UUAH.csv
# Delay for this recording sesssion is: 4.27341413497924 mins
# ----------------------------------
# baseline start time: 2023-02-10 10:34:38.529192+01:00
# task time: 2023-02-10 10:39:39.116452+01:00
# recovery time: 2023-02-10 10:44:40.118422+01:00
# ---------------------------------------------
# baseline start time: 2023-02-10 10:50:19.560652+01:00
# task time: 2023-02-10 10:55:20.288982+01:00
# recovery time: 2023-02-10 11:00:22.054072+01:00
# ---------------------------------------------
# baseline start time: 2023-02-10 11:16:40.985832+01:00
# task time: 2023-02-10 11:21:37.408932+01:00
# recovery time: 2023-02-10 11:26:40.639472+01:00
# ---------------------------------------------
# psychopy_events_WP2_P07_VCIP.csv
# Delay for this recording sesssion is: 3.9680986404418954 mins
# ----------------------------------
# baseline start time: 2023-02-10 13:22:31.305589+01:00
# task time: 2023-02-10 13:27:31.900460+01:00
# recovery time: 2023-02-10 13:32:32.907221+01:00
# ---------------------------------------------
# baseline start time: 2023-02-10 13:38:31.228277+01:00
# task time: 2023-02-10 13:43:31.961665+01:00
# recovery time: 2023-02-10 13:48:33.730602+01:00
# ---------------------------------------------
# baseline start time: 2023-02-10 14:00:43.637354+01:00
# task time: 2023-02-10 14:05:40.352275+01:00
# recovery time: 2023-02-10 14:10:42.548684+01:00
# ---------------------------------------------
# psychopy_events_WP2_P08_NYPX.csv
# Delay for this recording sesssion is: 40.3434991836547 mins
# ----------------------------------
# baseline start time: 2023-02-10 15:05:26.894659+01:00
# task time: 2023-02-10 15:10:27.473699+01:00
# recovery time: 2023-02-10 15:15:28.482299+01:00
# ---------------------------------------------
# baseline start time: 2023-02-10 15:21:29.042079+01:00
# task time: 2023-02-10 15:26:29.775239+01:00
# recovery time: 2023-02-10 15:31:31.537489+01:00
# ---------------------------------------------
# baseline start time: 2023-02-10 15:43:47.274029+01:00
# task time: 2023-02-10 15:48:43.898579+01:00
# recovery time: 2023-02-10 15:53:46.827949+01:00
# ---------------------------------------------
# psychopy_events_WP2_P09_CWAP.csv
# Delay for this recording sesssion is: 4.12902808189392 mins
# ----------------------------------
# baseline start time: 2023-02-13 10:29:39.820635+01:00
# task time: 2023-02-13 10:34:40.416135+01:00
# recovery time: 2023-02-13 10:39:41.416705+01:00
# ---------------------------------------------
# baseline start time: 2023-02-13 10:45:25.434465+01:00
# task time: 2023-02-13 10:50:26.035265+01:00
# recovery time: 2023-02-13 10:55:27.797795+01:00
# ---------------------------------------------
# baseline start time: 2023-02-13 11:07:53.087445+01:00
# task time: 2023-02-13 11:12:49.638435+01:00
# recovery time: 2023-02-13 11:17:51.393735+01:00
# ---------------------------------------------
# psychopy_events_WP2_P10_DNEE.csv
# Delay for this recording sesssion is: 4.16139197349548 mins
# ----------------------------------
# baseline start time: 2023-02-13 15:36:56.145042+01:00
# task time: 2023-02-13 15:41:56.733922+01:00
# recovery time: 2023-02-13 15:46:57.734892+01:00
# ---------------------------------------------
# baseline start time: 2023-02-13 15:53:29.736542+01:00
# task time: 2023-02-13 15:58:30.429152+01:00
# recovery time: 2023-02-13 16:03:32.471762+01:00
# ---------------------------------------------
# baseline start time: 2023-02-13 16:16:13.911002+01:00
# task time: 2023-02-13 16:21:10.395572+01:00
# recovery time: 2023-02-13 16:26:12.153552+01:00
# ---------------------------------------------
# psychopy_events_WP2_P11_TXTU.csv
# Delay for this recording sesssion is: 4.22730445861816 mins
# ----------------------------------
# baseline start time: 2023-02-14 10:34:25.773932+01:00
# task time: 2023-02-14 10:39:26.320602+01:00
# recovery time: 2023-02-14 10:44:27.323772+01:00
# ---------------------------------------------
# baseline start time: 2023-02-14 10:50:26.425642+01:00
# task time: 2023-02-14 10:55:27.139202+01:00
# recovery time: 2023-02-14 11:00:28.921202+01:00
# ---------------------------------------------
# baseline start time: 2023-02-14 11:13:04.364392+01:00
# task time: 2023-02-14 11:18:00.790032+01:00
# recovery time: 2023-02-14 11:23:02.567802+01:00
# ---------------------------------------------
# psychopy_events_WP2_P12_FMDS.csv
# Delay for this recording sesssion is: 4.11205434799194 mins
# ----------------------------------
# baseline start time: 2023-02-14 13:12:02.928109+01:00
# task time: 2023-02-14 13:17:03.505329+01:00
# recovery time: 2023-02-14 13:22:05.392019+01:00
# ---------------------------------------------
# baseline start time: 2023-02-14 13:28:21.423289+01:00
# task time: 2023-02-14 13:33:22.139879+01:00
# recovery time: 2023-02-14 13:38:23.896709+01:00
# ---------------------------------------------
# baseline start time: 2023-02-14 13:50:45.386649+01:00
# task time: 2023-02-14 13:55:41.912159+01:00
# recovery time: 2023-02-14 14:00:43.675509+01:00
# ---------------------------------------------
# psychopy_events_WP2_P13_NYBN.csv
# Delay for this recording sesssion is: 4.09293556213378 mins
# ----------------------------------
# baseline start time: 2023-02-14 15:40:12.842836+01:00
# task time: 2023-02-14 15:45:13.413506+01:00
# recovery time: 2023-02-14 15:50:14.415566+01:00
# ---------------------------------------------
# baseline start time: 2023-02-14 15:56:26.976116+01:00
# task time: 2023-02-14 16:01:27.574596+01:00
# recovery time: 2023-02-14 16:06:29.977936+01:00
# ---------------------------------------------
# baseline start time: 2023-02-14 16:18:50.496376+01:00
# task time: 2023-02-14 16:23:47.057666+01:00
# recovery time: 2023-02-14 16:28:49.870986+01:00
# ---------------------------------------------
# psychopy_events_WP2_P14_WHVF.csv
# Delay for this recording sesssion is: 432.735276222229 mins
# ----------------------------------
# baseline start time: 2023-02-15 03:18:00.432287+01:00
# task time: 2023-02-15 03:23:01.039247+01:00
# recovery time: 2023-02-15 03:28:02.045097+01:00
# ---------------------------------------------
# baseline start time: 2023-02-15 03:34:02.130897+01:00
# task time: 2023-02-15 03:39:02.855647+01:00
# recovery time: 2023-02-15 03:44:05.815817+01:00
# ---------------------------------------------
# baseline start time: 2023-02-15 03:56:27.248607+01:00
# task time: 2023-02-15 04:01:23.582467+01:00
# recovery time: 2023-02-15 04:06:25.349987+01:00
# ---------------------------------------------
# psychopy_events_WP2_P15_MDTP.csv
# Delay for this recording sesssion is: 4.14813876152038 mins
# ----------------------------------
# baseline start time: 2023-02-15 13:23:51.345474+01:00
# task time: 2023-02-15 13:28:51.938284+01:00
# recovery time: 2023-02-15 13:33:52.951904+01:00
# ---------------------------------------------
# baseline start time: 2023-02-15 13:39:33.801984+01:00
# task time: 2023-02-15 13:44:34.434394+01:00
# recovery time: 2023-02-15 13:49:36.724414+01:00
# ---------------------------------------------
# baseline start time: 2023-02-15 14:01:49.252024+01:00
# task time: 2023-02-15 14:06:45.768034+01:00
# recovery time: 2023-02-15 14:11:47.531574+01:00
# ---------------------------------------------
# psychopy_events_WP2_P16_MFFX.csv
# Delay for this recording sesssion is: 42.0371079444885 mins
# ----------------------------------
# baseline start time: 2023-02-15 15:29:49.351813+01:00
# task time: 2023-02-15 15:34:49.952973+01:00
# recovery time: 2023-02-15 15:39:50.959343+01:00
# ---------------------------------------------
# baseline start time: 2023-02-15 15:45:54.330503+01:00
# task time: 2023-02-15 15:50:54.976843+01:00
# recovery time: 2023-02-15 15:55:56.735463+01:00
# ---------------------------------------------
# baseline start time: 2023-02-15 16:08:24.784413+01:00
# task time: 2023-02-15 16:13:21.277683+01:00
# recovery time: 2023-02-15 16:18:24.135413+01:00
# ---------------------------------------------
# psychopy_events_WP2_P17_EKQV.csv
# Delay for this recording sesssion is: 4.329813241958618 mins
# ----------------------------------
# baseline start time: 2023-02-16 09:57:46.259363+01:00
# task time: 2023-02-16 10:02:46.890343+01:00
# recovery time: 2023-02-16 10:07:47.891612+01:00
# ---------------------------------------------
# baseline start time: 2023-02-16 10:14:03.668491+01:00
# task time: 2023-02-16 10:19:04.397437+01:00
# recovery time: 2023-02-16 10:24:06.787184+01:00
# ---------------------------------------------
# baseline start time: 2023-02-16 10:36:43.675461+01:00
# task time: 2023-02-16 10:41:40.057176+01:00
# recovery time: 2023-02-16 10:46:42.617018+01:00
# ---------------------------------------------
# psychopy_events_WP2_P18_HSSW.csv
# Delay for this recording sesssion is: 4.269686698913574 mins
# ----------------------------------
# baseline start time: 2023-02-17 09:57:54.973954+01:00
# task time: 2023-02-17 10:02:55.431554+01:00
# recovery time: 2023-02-17 10:07:56.946340+01:00
# ---------------------------------------------
# baseline start time: 2023-02-17 10:14:07.479236+01:00
# task time: 2023-02-17 10:19:08.200033+01:00
# recovery time: 2023-02-17 10:24:10.171866+01:00
# ---------------------------------------------
# baseline start time: 2023-02-17 10:36:48.056840+01:00
# task time: 2023-02-17 10:41:44.495765+01:00
# recovery time: 2023-02-17 10:46:46.264984+01:00
# ---------------------------------------------
# psychopy_events_WP2_P19_UHTF.csv
# Delay for this recording sesssion is: 3.9281585216522217 mins
# ----------------------------------
# baseline start time: 2023-02-17 13:14:31.567759+01:00
# task time: 2023-02-17 13:19:31.975704+01:00
# recovery time: 2023-02-17 13:24:33.346978+01:00
# ---------------------------------------------
# baseline start time: 2023-02-17 13:31:17.826233+01:00
# task time: 2023-02-17 13:36:18.341150+01:00
# recovery time: 2023-02-17 13:41:20.104561+01:00
# ---------------------------------------------
# baseline start time: 2023-02-17 13:54:09.824315+01:00
# task time: 2023-02-17 13:59:06.367702+01:00
# recovery time: 2023-02-17 14:04:08.121193+01:00
# ---------------------------------------------
# psychopy_events_WP2_P20_OBVP.csv
# Delay for this recording sesssion is: 4.149152994155884 mins
# ----------------------------------
# baseline start time: 2023-02-17 15:43:19.542776+01:00
# task time: 2023-02-17 15:48:19.944210+01:00
# recovery time: 2023-02-17 15:53:21.696768+01:00
# ---------------------------------------------
# baseline start time: 2023-02-17 15:59:39.894401+01:00
# task time: 2023-02-17 16:04:40.431558+01:00
# recovery time: 2023-02-17 16:09:42.283060+01:00
# ---------------------------------------------
# baseline start time: 2023-02-17 16:22:19.654572+01:00
# task time: 2023-02-17 16:27:15.995456+01:00
# recovery time: 2023-02-17 16:32:17.766418+01:00
# ---------------------------------------------
# psychopy_events_WP2_P22_RIXP.csv
# Delay for this recording sesssion is: 4.26434993743896 mins
# ----------------------------------
# baseline start time: 2023-02-21 13:26:02.938984+01:00
# task time: 2023-02-21 13:31:03.368074+01:00
# recovery time: 2023-02-21 13:36:04.383474+01:00
# ---------------------------------------------
# baseline start time: 2023-02-21 13:41:50.377514+01:00
# task time: 2023-02-21 13:46:50.933044+01:00
# recovery time: 2023-02-21 13:51:52.697304+01:00
# ---------------------------------------------
# baseline start time: 2023-02-21 14:04:20.413124+01:00
# task time: 2023-02-21 14:09:16.648624+01:00
# recovery time: 2023-02-21 14:14:18.396764+01:00
# ---------------------------------------------
# psychopy_events_WP2_P23_JQPD.csv
# Delay for this recording sesssion is: 404.633903503418 mins
# ----------------------------------
# baseline start time: 2023-02-22 03:16:53.147390+01:00
# task time: 2023-02-22 03:21:53.556970+01:00
# recovery time: 2023-02-22 03:26:54.569540+01:00
# ---------------------------------------------
# baseline start time: 2023-02-22 03:32:41.022850+01:00
# task time: 2023-02-22 03:37:41.442250+01:00
# recovery time: 2023-02-22 03:42:43.205230+01:00
# ---------------------------------------------
# baseline start time: 2023-02-22 03:55:01.900140+01:00
# task time: 2023-02-22 03:59:58.511960+01:00
# recovery time: 2023-02-22 04:05:00.638510+01:00
# ---------------------------------------------
# psychopy_events_WP2_P24_PPTC.csv
# Delay for this recording sesssion is: 38.4014821052551 mins
# ----------------------------------
# baseline start time: 2023-02-22 12:44:54.804684+01:00
# task time: 2023-02-22 12:49:55.212864+01:00
# recovery time: 2023-02-22 12:54:56.214124+01:00
# ---------------------------------------------
# baseline start time: 2023-02-22 13:01:04.627914+01:00
# task time: 2023-02-22 13:06:05.061524+01:00
# recovery time: 2023-02-22 13:11:06.814414+01:00
# ---------------------------------------------
# baseline start time: 2023-02-22 13:23:33.042464+01:00
# task time: 2023-02-22 13:28:29.668824+01:00
# recovery time: 2023-02-22 13:33:31.448994+01:00
# ---------------------------------------------
# psychopy_events_WP2_P25_CMRG.csv
# Delay for this recording sesssion is: 4.08246731758117 mins
# ----------------------------------
# baseline start time: 2023-02-22 16:26:17.291061+01:00
# task time: 2023-02-22 16:31:17.879391+01:00
# recovery time: 2023-02-22 16:36:18.891931+01:00
# ---------------------------------------------
# baseline start time: 2023-02-22 16:42:36.228281+01:00
# task time: 2023-02-22 16:47:36.914871+01:00
# recovery time: 2023-02-22 16:52:38.668111+01:00
# ---------------------------------------------
# baseline start time: 2023-02-22 17:04:48.565381+01:00
# task time: 2023-02-22 17:09:45.138761+01:00
# recovery time: 2023-02-22 17:14:47.703021+01:00
# ---------------------------------------------
# psychopy_events_WP2_P26_IRJH.csv
# Delay for this recording sesssion is: 40.9078860282897 mins
# ----------------------------------
# baseline start time: 2023-02-23 10:03:41.369868+01:00
# task time: 2023-02-23 10:08:41.797128+01:00
# recovery time: 2023-02-23 10:13:42.814508+01:00
# ---------------------------------------------
# baseline start time: 2023-02-23 10:20:01.219108+01:00
# task time: 2023-02-23 10:25:01.757288+01:00
# recovery time: 2023-02-23 10:30:03.947178+01:00
# ---------------------------------------------
# baseline start time: 2023-02-23 10:42:31.624798+01:00
# task time: 2023-02-23 10:47:28.050278+01:00
# recovery time: 2023-02-23 10:52:31.353818+01:00
# ---------------------------------------------
# psychopy_events_WP2_P27_VJBM.csv
# Delay for this recording sesssion is: 3.99862480163574 mins
# ----------------------------------
# baseline start time: 2023-02-23 13:24:14.801142+01:00
# task time: 2023-02-23 13:29:15.229152+01:00
# recovery time: 2023-02-23 13:34:16.236152+01:00
# ---------------------------------------------
# baseline start time: 2023-02-23 13:40:40.422402+01:00
# task time: 2023-02-23 13:45:40.849442+01:00
# recovery time: 2023-02-23 13:50:42.616582+01:00
# ---------------------------------------------
# baseline start time: 2023-02-23 14:03:40.309172+01:00
# task time: 2023-02-23 14:08:36.810602+01:00
# recovery time: 2023-02-23 14:13:38.569772+01:00
# ---------------------------------------------
# psychopy_events_WP2_P28_OSKE.csv
# Delay for this recording sesssion is: 39.1312766075134 mins
# ----------------------------------
# baseline start time: 2023-02-23 15:11:03.251154+01:00
# task time: 2023-02-23 15:16:03.656364+01:00
# recovery time: 2023-02-23 15:21:05.640754+01:00
# ---------------------------------------------
# baseline start time: 2023-02-23 15:26:51.707294+01:00
# task time: 2023-02-23 15:31:52.232774+01:00
# recovery time: 2023-02-23 15:36:53.992934+01:00
# ---------------------------------------------
# baseline start time: 2023-02-23 15:49:16.455684+01:00
# task time: 2023-02-23 15:54:13.000424+01:00
# recovery time: 2023-02-23 15:59:14.762054+01:00
# ---------------------------------------------
# psychopy_events_WP2_P29_GMIP.csv
# Delay for this recording sesssion is: 4.16155385971069 mins
# ----------------------------------
# baseline start time: 2023-02-24 10:24:59.399978+01:00
# task time: 2023-02-24 10:29:59.818508+01:00
# recovery time: 2023-02-24 10:35:00.825058+01:00
# ---------------------------------------------
# baseline start time: 2023-02-24 10:41:13.034068+01:00
# task time: 2023-02-24 10:46:13.546188+01:00
# recovery time: 2023-02-24 10:51:15.720748+01:00
# ---------------------------------------------
# baseline start time: 2023-02-24 11:03:41.033388+01:00
# task time: 2023-02-24 11:08:37.352108+01:00
# recovery time: 2023-02-24 11:13:39.112158+01:00
# ---------------------------------------------
# psychopy_events_WP2_P30_ZCTR.csv
# Delay for this recording sesssion is: 3.98078298568725 mins
# ----------------------------------
# baseline start time: 2023-02-24 14:19:20.716121+01:00
# task time: 2023-02-24 14:24:21.138251+01:00
# recovery time: 2023-02-24 14:29:22.149591+01:00
# ---------------------------------------------
# baseline start time: 2023-02-24 14:35:37.929091+01:00
# task time: 2023-02-24 14:40:38.440121+01:00
# recovery time: 2023-02-24 14:45:40.606731+01:00
# ---------------------------------------------
# baseline start time: 2023-02-24 14:58:32.315301+01:00
# task time: 2023-02-24 15:03:28.840881+01:00
# recovery time: 2023-02-24 15:08:30.970541+01:00
# ---------------------------------------------
# psychopy_events_WP2_P31_WDDN.csv
# Delay for this recording sesssion is: 4.62002611160278 mins
# ----------------------------------
# baseline start time: 2023-02-27 10:45:44.318143+01:00
# task time: 2023-02-27 10:50:44.921303+01:00
# recovery time: 2023-02-27 10:55:45.932843+01:00
# ---------------------------------------------
# baseline start time: 2023-02-27 11:01:26.188993+01:00
# task time: 2023-02-27 11:06:26.806153+01:00
# recovery time: 2023-02-27 11:11:28.588763+01:00
# ---------------------------------------------
# baseline start time: 2023-02-27 11:23:43.251023+01:00
# task time: 2023-02-27 11:28:39.343013+01:00
# recovery time: 2023-02-27 11:33:41.107783+01:00
# ---------------------------------------------

# %%
path_psychopy_events_file = "D:/Datasets/Dataset_Sony_TEAA/Psychopy_Events/psychopy_events_WP2_P14_WHVF.csv"

try:
    psy_events_df = pd.read_csv(sel_event_file, sep=";", index_col="Unnamed: 0")
except:
    psy_events_df = pd.read_csv(sel_event_file, index_col="Unnamed: 0")
# Out:
#                          reference(start)          reference(exp)  \
# fam                 1.677.491.101.828.520  16.774.911.325.782.700
# pa                  1.677.491.101.828.520  16.774.911.325.782.700
# b1                  1.677.491.101.828.520  16.774.911.325.782.700
# b2                  1.677.491.101.828.520  16.774.911.325.782.700
# relax_onset         1.677.491.101.828.520  16.774.911.325.782.700
# relax_offset        1.677.491.101.828.520  16.774.911.325.782.700
# relax_onset(unix)   1.677.491.101.828.520  16.774.911.325.782.700
# relax_offset(unix)  1.677.491.101.828.520  16.774.911.325.782.700
# eeg_trigger_first   1.677.491.101.828.520  16.774.911.325.782.700
# eeg_trigger_last    1.677.491.101.828.520  16.774.911.325.782.700
# acc_trigger_first   1.677.491.101.828.520  16.774.911.325.782.700
# acc_trigger_last    1.677.491.101.828.520  16.774.911.325.782.700
# b1_type             1.677.491.101.828.520  16.774.911.325.782.700
# b2_type             1.677.491.101.828.520  16.774.911.325.782.700
#
#                                    offset          baseline_onset  \
# fam                 4.620.026.111.602.780   1.677.491.195.077.370
# pa                  4.620.026.111.602.780  16.774.914.261.591.400
# b1                  4.620.026.111.602.780  16.774.923.680.297.800
# b2                  4.620.026.111.602.780  16.774.937.004.525.900
# relax_onset         4.620.026.111.602.780                     NaN
# relax_offset        4.620.026.111.602.780                     NaN
# relax_onset(unix)   4.620.026.111.602.780                     NaN
# relax_offset(unix)  4.620.026.111.602.780                     NaN
# eeg_trigger_first   4.620.026.111.602.780                     NaN
# eeg_trigger_last    4.620.026.111.602.780                     NaN
# acc_trigger_first   4.620.026.111.602.780                     NaN
# acc_trigger_last    4.620.026.111.602.780                     NaN
# b1_type             4.620.026.111.602.780                     NaN
# b2_type             4.620.026.111.602.780                     NaN
#
#                       baseline_onset(unix)              task_onset  \
# fam                 16.774.911.904.373.700  16.774.912.066.272.500
# pa                  16.774.914.215.197.100  16.774.917.267.599.000
# b1                  16.774.923.633.905.600   1.677.492.668.639.750
# b2                  16.774.936.958.127.900  16.774.940.011.779.600
# relax_onset                            NaN                     NaN
# relax_offset                           NaN                     NaN
# relax_onset(unix)                      NaN                     NaN
# relax_offset(unix)                     NaN                     NaN
# eeg_trigger_first                      NaN                     NaN
# eeg_trigger_last                       NaN                     NaN
# acc_trigger_first                      NaN                     NaN
# acc_trigger_last                       NaN                     NaN
# b1_type                                NaN                     NaN
# b2_type                                NaN                     NaN
#
#                           task_onset(unix)          recovery_onset  \
# fam                 16.774.912.019.882.700   1.677.491.236.643.720
# pa                  16.774.917.221.228.700  16.774.920.277.748.100
# b1                   1.677.492.664.007.720  16.774.929.704.316.700
# b2                  16.774.939.965.445.800   1.677.494.302.949.890
# relax_onset                            NaN                     NaN
# relax_offset                           NaN                     NaN
# relax_onset(unix)                      NaN                     NaN
# relax_offset(unix)                     NaN                     NaN
# eeg_trigger_first                      NaN                     NaN
# eeg_trigger_last                       NaN                     NaN
# acc_trigger_first                      NaN                     NaN
# acc_trigger_last                       NaN                     NaN
# b1_type                                NaN                     NaN
# b2_type                                NaN                     NaN
#
#                       recovery_onset(unix)                 1st_VAS  \
# fam                 16.774.912.320.030.900  16.774.913.956.490.000
# pa                     167.749.202.313.441   1.677.492.327.819.500
# b1                  16.774.929.657.903.300  16.774.932.705.758.100
# b2                   1.677.494.298.309.350     167.749.460.301.124
# relax_onset                            NaN                     NaN
# relax_offset                           NaN                     NaN
# relax_onset(unix)                      NaN                     NaN
# relax_offset(unix)                     NaN                     NaN
# eeg_trigger_first                      NaN                     NaN
# eeg_trigger_last                       NaN                     NaN
# acc_trigger_first                      NaN                     NaN
# acc_trigger_last                       NaN                     NaN
# b1_type                                NaN                     NaN
# b2_type                                NaN                     NaN
#
#                              1st_VAS(unix)              relaxation  \
# fam                  1.677.491.390.995.910                     NaN
# pa                  16.774.923.231.588.200                     NaN
# b1                  16.774.932.659.189.400                     NaN
# b2                  16.774.945.983.487.700                     NaN
# relax_onset                            NaN  16.774.933.104.298.300
# relax_offset                           NaN  16.774.937.004.525.900
# relax_onset(unix)                      NaN                     NaN
# relax_offset(unix)                     NaN                     NaN
# eeg_trigger_first                      NaN                     NaN
# eeg_trigger_last                       NaN                     NaN
# acc_trigger_first                      NaN                     NaN
# acc_trigger_last                       NaN                     NaN
# b1_type                                NaN                     NaN
# b2_type                                NaN                     NaN
#
#                           relaxation(unix)                     EOE  \
# fam                                    NaN  16.774.947.327.277.400
# pa                                     NaN  16.774.947.327.277.400
# b1                                     NaN  16.774.947.327.277.400
# b2                                     NaN  16.774.947.327.277.400
# relax_onset                            NaN  16.774.947.327.277.400
# relax_offset                           NaN  16.774.947.327.277.400
# relax_onset(unix)   16.774.933.092.280.200  16.774.947.327.277.400
# relax_offset(unix)  16.774.936.958.127.900  16.774.947.327.277.400
# eeg_trigger_first                      NaN  16.774.947.327.277.400
# eeg_trigger_last                       NaN  16.774.947.327.277.400
# acc_trigger_first                      NaN  16.774.947.327.277.400
# acc_trigger_last                       NaN  16.774.947.327.277.400
# b1_type                                NaN  16.774.947.327.277.400
# b2_type                                NaN  16.774.947.327.277.400
#
#                                  EOE(unix)      sync_signals(unix) block_type  \
# fam                 16.774.947.281.077.100                     NaN        NaN
# pa                  16.774.947.281.077.100                     NaN        NaN
# b1                  16.774.947.281.077.100                     NaN        NaN
# b2                  16.774.947.281.077.100                     NaN        NaN
# relax_onset         16.774.947.281.077.100                     NaN        NaN
# relax_offset        16.774.947.281.077.100                     NaN        NaN
# relax_onset(unix)   16.774.947.281.077.100                     NaN        NaN
# relax_offset(unix)  16.774.947.281.077.100                     NaN        NaN
# eeg_trigger_first   16.774.947.281.077.100  16.774.911.447.042.100        NaN
# eeg_trigger_last    16.774.947.281.077.100   1.677.494.701.508.190        NaN
# acc_trigger_first   16.774.947.281.077.100   1.677.491.158.770.590        NaN
# acc_trigger_last    16.774.947.281.077.100  16.774.947.158.413.000        NaN
# b1_type             16.774.947.281.077.100                     NaN   positive
# b2_type             16.774.947.281.077.100                     NaN   negative
#
#                     total_reward  accuracy               averageRT
# fam                        113.0  0.333333  29.465.410.000.000.200
# pa                         113.0  0.687500  26.450.157.694.445.800
# b1                         113.0  0.701149   2.012.667.535.714.360
# b2                         113.0  0.750000  20.432.291.546.513.400
# relax_onset                113.0       NaN                     NaN
# relax_offset               113.0       NaN                     NaN
# relax_onset(unix)          113.0       NaN                     NaN
# relax_offset(unix)         113.0       NaN                     NaN
# eeg_trigger_first          113.0       NaN                     NaN
# eeg_trigger_last           113.0       NaN                     NaN
# acc_trigger_first          113.0       NaN                     NaN
# acc_trigger_last           113.0       NaN                     NaN
# b1_type                    113.0       NaN                     NaN
# b2_type                    113.0       NaN                     NaN

# %%
pa_row=psy_events_df.loc["pa"]
b1_row=psy_events_df.loc["b1"]
b2_row=psy_events_df.loc["b2"]
b1_type=psy_events_df.loc["b1_type"]["block_type"]
b2_type=psy_events_df.loc["b2_type"]["block_type"]

offset_mins = pa_row["offset"]

# %%
baseline_onset_pa=pa_row["baseline_onset(unix)"]
baseline_onset_pa=from_excel_val_to_timestamp(baseline_onset_pa)
baseline_onset_b1=b1_row["baseline_onset(unix)"]
baseline_onset_b1=from_excel_val_to_timestamp(baseline_onset_b1)
baseline_onset_b2=b2_row["baseline_onset"]
baseline_onset_b2=from_excel_val_to_timestamp(baseline_onset_b2)

baseline_onset_timestamps = []
baseline_onset_timestamps.append(baseline_onset_pa)
baseline_onset_timestamps.append(baseline_onset_b1)
baseline_onset_timestamps.append(baseline_onset_b2)

task_onset_pa = pa_row["task_onset(unix)"]
task_onset_pa=from_excel_val_to_timestamp(task_onset_pa)
task_onset_b1=b1_row["task_onset(unix)"]
task_onset_b1=from_excel_val_to_timestamp(task_onset_b1)
task_onset_b2 = b2_row["task_onset(unix)"]
task_onset_b2=from_excel_val_to_timestamp(task_onset_b2)

task_onset_float_timestamp = []
task_onset_float_timestamp.append(task_onset_pa)
task_onset_float_timestamp.append(task_onset_b1)
task_onset_float_timestamp.append(task_onset_b2)

recovery_onset_pa = pa_row["recovery_onset(unix)"]
recovery_onset_pa=from_excel_val_to_timestamp(recovery_onset_pa)
recovery_onset_b1=b1_row["recovery_onset(unix)"]
recovery_onset_b1=from_excel_val_to_timestamp(recovery_onset_b1)
recovery_onset_b2 = b2_row["recovery_onset(unix)"]
recovery_onset_b2=from_excel_val_to_timestamp(recovery_onset_b2)

recovery_onset_list_timestamps = []
recovery_onset_list_timestamps.append(recovery_onset_pa)
recovery_onset_list_timestamps.append(recovery_onset_b1)
recovery_onset_list_timestamps.append(recovery_onset_b2)

# %%
print(baseline_onset_timestamps)
print(task_onset_float_timestamp)
print(recovery_onset_list_timestamps)
# Out:
# [1676367519.4122, 1676368480.06391, 1676369838.00266]
# [1676367819.95887, 1676368780.77747, 1676370134.4283]
# [1676368120.96204, 1676369082.55947, 1676370436.20607]

# %%
delay_mins= from_excel_val_to_mins(pa_row["offset"])
print("Delay for this recording sesssion is: " + str(delay_mins)+ " mins")
print("----------------------------------")
for ind_ii, sel_baseline in enumerate(baseline_onset_timestamps):
    
    baseline_ts = sel_baseline
    baseline_ts = get_delayed_psychopy_timestamp(baseline_ts, delay_mins)
    
    baseline_time = dt.datetime.fromtimestamp(baseline_ts, tz)
    print("baseline start time: "+str(baseline_time))
    ##------------------------------------------
    task_ts = task_onset_float_timestamp[ind_ii]
    task_ts = get_delayed_psychopy_timestamp(task_ts, delay_mins)
    
    task_time = dt.datetime.fromtimestamp(task_ts, tz)
    print("task time: "+str(task_time))
    recovery_ts = recovery_onset_list_timestamps[ind_ii]
    recovery_ts = get_delayed_psychopy_timestamp(recovery_ts, delay_mins)
    recovery_time = dt.datetime.fromtimestamp(recovery_ts, tz)
    
    print("recovery time: "+str(recovery_time))
    
    print("---------------------------------------------")
# Out:
# Delay for this recording sesssion is: 4.22730445861816 mins
# ----------------------------------
# baseline start time: 2023-02-14 10:34:25.773932+01:00
# task time: 2023-02-14 10:39:26.320602+01:00
# recovery time: 2023-02-14 10:44:27.323772+01:00
# ---------------------------------------------
# baseline start time: 2023-02-14 10:50:26.425642+01:00
# task time: 2023-02-14 10:55:27.139202+01:00
# recovery time: 2023-02-14 11:00:28.921202+01:00
# ---------------------------------------------
# baseline start time: 2023-02-14 11:13:04.364392+01:00
# task time: 2023-02-14 11:18:00.790032+01:00
# recovery time: 2023-02-14 11:23:02.567802+01:00
# ---------------------------------------------

# %%
delay_mins
# Out:
# 4.22730445861816

# %%
ref_time_pa=pa_row["reference(start)"]
ref_time_b1=b1_row["reference(start)"]
ref_time_b2=b2_row["reference(start)"]

# %% [markdown]
# ## Baseline Onset

# %% [markdown]
# ## Read shimmer data

# %%
#shimmer_path = "/media/muhammad/d5e4618d-a960-4f0d-a521-1c804bbebbb4/dataset_sony_TEAA/WP2_P02_YPCK/Shimmer/2023-02-08_12.24.49_WP2_P02_YPCK_SD_Session1/WP2_P02_YPCK_Session1_Shimmer_DA83_Calibrated_SD.csv"
shimmer_path = "D:/Datasets/Dataset_Sony_TEAA/DataSet/WP2_P04_TUYR/Shimmer/WP2_P04_TUYR_Session1_Shimmer_DA83_Calibrated_SD.csv"
shimmer_df=read_shimmer_sensor(shimmer_path)

# %%
shimmer_df
# Out:
# 0       Shimmer_DA83_Timestamp_Unix_CAL Shimmer_DA83_Accel_LN_X_CAL  \
# 0                 1.6759339327063904E12          -9.421686746987952
# 1                  1.675933932714203E12          -9.397590361445783
# 2                 1.6759339327181091E12          -9.409638554216867
# 3                 1.6759339327220154E12          -9.397590361445783
# 4                 1.6759339327259216E12          -9.409638554216867
# ...                                 ...                         ...
# 1059011           1.6759380740774841E12          -9.506024096385543
# 1059012           1.6759380740813904E12          -9.493975903614459
# 1059013           1.6759380740852966E12          -9.506024096385543
# 1059014            1.675938074089203E12          -9.518072289156628
# 1059015           1.6759380740931091E12          -9.518072289156628
#
# 0       Shimmer_DA83_Accel_LN_Y_CAL Shimmer_DA83_Accel_LN_Z_CAL  \
# 0               -0.2530120481927711         -1.5060240963855422
# 1              -0.24096385542168675          -1.493975903614458
# 2               -0.2530120481927711          -1.493975903614458
# 3              -0.24096385542168675          -1.493975903614458
# 4              -0.24096385542168675         -1.4819277108433735
# ...                             ...                         ...
# 1059011       -0.024096385542168676          -0.855421686746988
# 1059012       -0.024096385542168676         -0.8674698795180723
# 1059013       -0.024096385542168676          -0.855421686746988
# 1059014       -0.012048192771084338          -0.855421686746988
# 1059015       -0.012048192771084338         -0.8433734939759037
#
# 0       Shimmer_DA83_ECG_EMG_Status1_CAL Shimmer_DA83_ECG_EMG_Status2_CAL  \
# 0                                  128.0                            128.0
# 1                                  128.0                            128.0
# 2                                  128.0                            128.0
# 3                                  128.0                            128.0
# 4                                  128.0                            128.0
# ...                                  ...                              ...
# 1059011                            128.0                            128.0
# 1059012                            128.0                            128.0
# 1059013                            128.0                            128.0
# 1059014                            128.0                            128.0
# 1059015                            128.0                            128.0
#
# 0       Shimmer_DA83_ECG_IBI_LA_RA_CAL Shimmer_DA83_ECG_IBI_LL_LA_CAL  \
# 0                                 -1.0                           -1.0
# 1                                 -1.0                           -1.0
# 2                                 -1.0                           -1.0
# 3                                 -1.0                           -1.0
# 4                                 -1.0                           -1.0
# ...                                ...                            ...
# 1059011                           -1.0                           -1.0
# 1059012                           -1.0                           -1.0
# 1059013                           -1.0                           -1.0
# 1059014                           -1.0                           -1.0
# 1059015                           -1.0                           -1.0
#
# 0       Shimmer_DA83_ECG_IBI_LL_RA_CAL Shimmer_DA83_ECG_IBI_Vx_RL_CAL  \
# 0                                 -1.0                           -1.0
# 1                                 -1.0                           -1.0
# 2                                 -1.0                           -1.0
# 3                                 -1.0                           -1.0
# 4                                 -1.0                           -1.0
# ...                                ...                            ...
# 1059011                           -1.0                           -1.0
# 1059012                           -1.0                           -1.0
# 1059013                           -1.0                           -1.0
# 1059014                           -1.0                           -1.0
# 1059015                           -1.0                           -1.0
#
# 0       Shimmer_DA83_ECG_LA-RA_24BIT_CAL Shimmer_DA83_ECG_LL-LA_24BIT_CAL  \
# 0                      8.047691946946616               10.035436157636186
# 1                      8.043436770848844                10.04221559074111
# 2                      8.049062257893356               10.026348832410436
# 3                      8.063486583648514                10.02988279222045
# 4                       8.06543386762546               10.035219792749858
# ...                                  ...                              ...
# 1059011               2.7511516512813152                6.351535481397567
# 1059012                2.760022611620738                6.337255398899961
# 1059013               2.7621862604840115                6.327951708787884
# 1059014               2.7549019759776567                6.335885087953221
# 1059015               2.7346357982916594                 6.32989899276483
#
# 0       Shimmer_DA83_ECG_LL-RA_24BIT_CAL Shimmer_DA83_ECG_Vx-RL_24BIT_CAL  \
# 0                       18.0831281045828              -15.059573061415323
# 1                     18.085652361589954              -15.037215356494828
# 2                     18.075411090303792              -15.023079517254773
# 3                     18.093369375868964              -14.926436534695213
# 4                      18.10065366037532              -14.920955290908253
# ...                                  ...                              ...
# 1059011                9.102687132678883               -9.404876757249447
# 1059012                9.097278010520698               -9.404876757249447
# 1059013                9.090137969271895               -9.322946586960148
# 1059014                9.090787063930877               -9.322946586960148
# 1059015                 9.06453479105649               -9.407761622400479
#
# 0       Shimmer_DA83_ECGtoHR_LA_RA_CAL Shimmer_DA83_ECGtoHR_LL_LA_CAL  \
# 0                                 -1.0                           -1.0
# 1                                 -1.0                           -1.0
# 2                                 -1.0                           -1.0
# 3                                 -1.0                           -1.0
# 4                                 -1.0                           -1.0
# ...                                ...                            ...
# 1059011              73.84615384615385              74.20289855072464
# 1059012              73.84615384615385              74.20289855072464
# 1059013              73.84615384615385              74.20289855072464
# 1059014              73.84615384615385              74.20289855072464
# 1059015              73.84615384615385              74.20289855072464
#
# 0       Shimmer_DA83_ECGtoHR_LL_RA_CAL Shimmer_DA83_ECGtoHR_Vx_RL_CAL  NaN
# 0                                 -1.0                           -1.0  NaN
# 1                                 -1.0                           -1.0  NaN
# 2                                 -1.0                           -1.0  NaN
# 3                                 -1.0                           -1.0  NaN
# 4                                 -1.0                           -1.0  NaN
# ...                                ...                            ...  ...
# 1059011              74.20289855072464              73.84615384615385  NaN
# 1059012              74.20289855072464              73.84615384615385  NaN
# 1059013              74.20289855072464              73.84615384615385  NaN
# 1059014              74.20289855072464              73.84615384615385  NaN
# 1059015              74.20289855072464              73.84615384615385  NaN
#
# [1059016 rows x 19 columns]

# %%
shimmer_ts_col_name = "Shimmer_DA83_Timestamp_Unix_CAL"
shimmer_df=standardize_timestamps_shimmer(shimmer_df, shimmer_ts_col_name)
sh_ts_list = shimmer_df[shimmer_ts_col_name].values

# %%
shimmer_start_time = dt.datetime.fromtimestamp(sh_ts_list[0], tz)
print("shimmer first ts: "+ str(shimmer_start_time))

shimmer_stop_time = dt.datetime.fromtimestamp(sh_ts_list[-1], tz)
print("shimmer last ts: "+ str(shimmer_stop_time))
# Out:
# shimmer first ts: 2023-02-09 10:12:12.706390+01:00
# shimmer last ts: 2023-02-09 11:21:14.093109+01:00

# %% [markdown]
# # ----------------------------------------------------------
# ## Cummulative --------------------------------------------
# # ---------------------------------------------------------

# %%
data_dir_path = "/media/muhammad/d5e4618d-a960-4f0d-a521-1c804bbebbb4/dataset_sony_sam_2024/WP2"
sub_dirs=next(os.walk(data_dir_path))[1]
sub_dirs=sorted(sub_dirs)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19236\2793821425.py in <module>
#       1 data_dir_path = "/media/muhammad/d5e4618d-a960-4f0d-a521-1c804bbebbb4/dataset_sony_sam_2024/WP2"
# ----> 2 sub_dirs=next(os.walk(data_dir_path))[1]
#       3 sub_dirs=sorted(sub_dirs)
#
# StopIteration:

# %%
dest_path = "/home/muhammad/Desktop/Datasets/dataset_sony_sam/Data_analysis_ECG/pkld_file_per_subject_per_task"

# %%
sampling_freq_shimmer = 256
offset_min = 5
time_zone = 'Europe/Berlin'
tz = pytz.timezone(time_zone)

for sub_dir in sub_dirs:
    ###-----------------------------------------------
    #### reading psychopy, events, shimmer files
    ##----------------------------------------------
    
    sub_dir_path= os.path.join(data_dir_path, sub_dir)
    psychopy_file_path = os.path.join(sub_dir_path, "Psychopy")
    psychopy_file_path = glob.glob(psychopy_file_path+ "/*.csv")[0]
    #print(psychopy_file_path)
    events_path_list = os.path.join(sub_dir_path, "preAnalysis")
    events_path_list = glob.glob(events_path_list+ "/*.csv")
    
    for sel_event_path in events_path_list:
        fol_path, file_name_ii=os.path.split(sel_event_path)
        #print(file_name_ii)
        if "trigger" in file_name_ii:
            sel_trigger_file = sel_event_path
            
            fol_path_tri, file_name_trig=os.path.split(sel_trigger_file)
            
            print(file_name_trig)
            
    shimmer_files_subdir = os.path.join(sub_dir_path, "Shimmer")
    shimmer_files_subdir_subdir_name = next(os.walk(shimmer_files_subdir))[1][0]
    shimmer_files_parent_path = os.path.join(shimmer_files_subdir, shimmer_files_subdir_subdir_name)
    shimmer_files_name = glob.glob(shimmer_files_parent_path+ "/*.csv")
    
    for sh_file in shimmer_files_name:
        
        if '_8943_' in sh_file:
            ecg_shimmer_path = sh_file
            shimmer_timestamp_col_name = "Shimmer_8943_Timestamp_Unix_CAL"
            ecg_col_name = "Shimmer_8943_ECG_LA-RA_24BIT_CAL"
        elif "_8108_" in sh_file:
            ecg_shimmer_path=sh_file
            shimmer_timestamp_col_name = "Shimmer_8108_Timestamp_Unix_CAL"
            ecg_col_name = "Shimmer_8108_ECG_LA-RA_24BIT_CAL"
            
            
            
            
            
            
    psychopy_df = pd.read_csv(psychopy_file_path)
    block_1_type = psychopy_df["block1"][0]
    #print(block_1_type)
    
    event_timestamps_df = pd.read_csv(sel_trigger_file)
    
    baseline_onset = event_timestamps_df["baseline_onset"].values
    baseline_onset_timestamps = baseline_onset[1:]
    task_onset =event_timestamps_df["task_onset"].values
    task_onset_str_timestamps = task_onset[1:]
    task_onset_float_timestamp = from_str_to_float(task_onset_str_timestamps)
    recovery_onset =event_timestamps_df["recovery_onset"].values
    recovery_onset_str_timestamps = recovery_onset[1:]
    recovery_onset_list_timestamps=from_str_to_float(recovery_onset_str_timestamps)
    
    
    shimmer_df=read_shimmer_sensor(ecg_shimmer_path)
    
    selected_ecg_df = shimmer_df[[shimmer_timestamp_col_name, ecg_col_name]]
    selected_ecg_df = selected_ecg_df.copy()
    selected_ecg_df=standardize_timestamps_shimmer(selected_ecg_df, shimmer_timestamp_col_name)
    selected_ecg_df['ecg'] = selected_ecg_df[ecg_col_name]
    selected_ecg_df=col_from_str_float(selected_ecg_df, "ecg")
    
    ###-------------------------------------------------------
    ####-----------------------------------------------------
    ###-------------------------------------------------------
    
    #all_ibi_one_list_one_task = []
    #all_ibi_sublist_one_task = []
    
    
    for ind_timestamp, sel_baseline in enumerate(baseline_onset_timestamps):
        task_type_list = []
        all_ibi_one_list_one_task = []
        all_ibi_sublist_one_task = []
        mean_cumm_list = []
        std_cumm_list = []
        
        mean_hbpm_cumm_list = []
        std_hbpm_cumm_list = []
        
        if ind_timestamp==0:
            task_type_ii = "pre_assesment"
        
        elif ind_timestamp==1:
            if block_1_type=="negative":
                task_type_ii = "negative"
            elif block_1_type =="positive":
                task_type_ii = "positive"
        
        elif ind_timestamp==2:
            if block_1_type=="positive":
                task_type_ii = "negative"
            elif block_1_type =="negative":
                task_type_ii = "positive"
                
        #elif ind_timestamp==2:
        #    if block_1_type=="negative":
        #       task_type_ii = "positive"
        #    elif block_1_type =="positive":
        #        task_type_ii = "negative"
                
        print(task_type_ii)
        task_type_list.append(task_type_ii)           
        start_timestamp_baseline = sel_baseline
        stop_timestamp_baseline = get_offset_timestamp(start_timestamp_baseline, offset_min)


        sliced_ecg_df_baseline=slice_df_wrt_timestamps(selected_ecg_df, start_timestamp_baseline, stop_timestamp_baseline, shimmer_timestamp_col_name)
        sliced_ecg_df_baseline=sliced_ecg_df_baseline.reset_index(drop=True)
        ecg_array_baseline = sliced_ecg_df_baseline["ecg"].values
        out_baseline = ecg.ecg(signal=ecg_array_baseline, sampling_rate=sampling_freq_shimmer, show=False, interactive=False)
        sliced_ecg_df_baseline["filtered"] = out_baseline["filtered"]
        r_peaks_ind_baseline = out_baseline["rpeaks"]
        rr_msec_baseline=from_rr_ind_2_msec(r_peaks_ind_baseline)
        rr_msec_baseline_clean=remove_outliers_rri(rr_msec_baseline, sampling_freq = 256, outlier_std = 1.5)
        
        time_domain_features=timedomain(rr_msec_baseline_clean)
        ###--------------------------------------------------
        mean_hbpm_baseline = time_domain_features["Mean HR (beats/min)"]
        std_hbpm_baseline = time_domain_features["STD HR (beats/min)"]
        
        
        
        all_ibi_one_list_one_task.extend(rr_msec_baseline_clean)
        all_ibi_sublist_one_task.append(rr_msec_baseline_clean)
        #mean_ibi = np.mean(rr_msec_baseline_clean)
        mean_cumm_list.append(np.mean(rr_msec_baseline_clean))
        std_cumm_list.append(np.std(rr_msec_baseline_clean))
        
        mean_hbpm_cumm_list.append(mean_hbpm_baseline)
        std_hbpm_cumm_list.append(std_hbpm_baseline)
    
        #print("BASELINE DATA")
        #fig_name = "Baseline_"+ sub_id + ".png"
        #fig_name = "Baseline"+str(ind_timestamp)+".png"
        #plt_title_raw = "Raw ECG: Baseline"
        #plt_title_filtered = "Filtered ECG: Baseline"
        #plot_ecg_wf(sliced_ecg_df_baseline,r_peaks_ind_baseline,offset_min,dest_path_save_figures, fig_name, nr_plots=total_plots, fig_title_raw=plt_title_raw, fig_title_filtered=plt_title_filtered)
    
    
    
        ####--------------------------------------------------------------------
        ####------------------for debugging purposes----------------------------
        ####--------------------------------------------------------------------
        start_time = dt.datetime.fromtimestamp(start_timestamp_baseline, tz)
        end_time  = dt.datetime.fromtimestamp(stop_timestamp_baseline, tz)

        print("baseline start time: "+str(start_time))
        print("baseline stop time: "+str(end_time))

        time_stamps_shimmer= sliced_ecg_df_baseline[shimmer_timestamp_col_name].values

        start_timestamp_shimmer = time_stamps_shimmer[0]
        end_timestamp_shimmer =  time_stamps_shimmer[-1]

        start_time = dt.datetime.fromtimestamp(start_timestamp_shimmer, tz)
        end_time  = dt.datetime.fromtimestamp(end_timestamp_shimmer, tz)

        print("shimmer_baseline start time: "+str(start_time))
        print("shimmer_baseline stop time: "+str(end_time))
    
        ####------------------------------------------------------------------

        start_timestamp_task= task_onset_float_timestamp[ind_timestamp]
        stop_timestamp_task = get_offset_timestamp(start_timestamp_task, offset_min)
        sliced_ecg_df_task=slice_df_wrt_timestamps(selected_ecg_df, start_timestamp_task, stop_timestamp_task, shimmer_timestamp_col_name)
        sliced_ecg_df_task=sliced_ecg_df_task.reset_index(drop=True)
        ###-------------------------------------------------
        ecg_array_task = sliced_ecg_df_task["ecg"].values
        out_task = ecg.ecg(signal=ecg_array_task, sampling_rate=sampling_freq_shimmer, show=False, interactive=False)
        sliced_ecg_df_task["filtered"] = out_task["filtered"]
        r_peaks_ind_task = out_task["rpeaks"]
        rr_msec_task=from_rr_ind_2_msec(r_peaks_ind_task)
        rr_msec_task_clean=remove_outliers_rri(rr_msec_task, sampling_freq = 256, outlier_std = 1.5)
        
        time_domain_features=timedomain(rr_msec_task_clean)
        ###--------------------------------------------------
        mean_hbpm_task = time_domain_features["Mean HR (beats/min)"]
        std_hbpm_task = time_domain_features["STD HR (beats/min)"]
        
        all_ibi_one_list_one_task.extend(rr_msec_task_clean)
        all_ibi_sublist_one_task.append(rr_msec_task_clean)
        
        mean_cumm_list.append(np.mean(rr_msec_task_clean))
        std_cumm_list.append(np.std(rr_msec_task_clean))
        
        mean_hbpm_cumm_list.append(mean_hbpm_task)
        std_hbpm_cumm_list.append(std_hbpm_task)
        
        #print("TASK DATA")
        #fig_name = "Task"+ sub_id + ".png"
        #fig_name = "Task"+str(ind_timestamp)+".png"
        #plt_title_raw = "Raw ECG: Task"
        #plt_title_filtered = "Filtered ECG: Task"
        #plot_ecg_wf(sliced_ecg_df_task,r_peaks_ind_task,offset_min, dest_path_save_figures,fig_name, 
         #           nr_plots=total_plots, fig_title_raw=plt_title_raw, fig_title_filtered=plt_title_filtered)
    
        #####------------------------------------------------------------
        ##### -------------for debugging---------------------------------
        #####------------------------------------------------------------

        start_time = dt.datetime.fromtimestamp(start_timestamp_task, tz)
        end_time  = dt.datetime.fromtimestamp(stop_timestamp_task, tz)

        print("task start time: "+str(start_time))
        print("task stop time: "+str(end_time))

        time_stamps_shimmer= sliced_ecg_df_task[shimmer_timestamp_col_name].values

        start_timestamp_shimmer = time_stamps_shimmer[0]
        end_timestamp_shimmer =  time_stamps_shimmer[-1]

        start_time = dt.datetime.fromtimestamp(start_timestamp_shimmer, tz)
        end_time  = dt.datetime.fromtimestamp(end_timestamp_shimmer, tz)

        print("shimmer_task start time: "+str(start_time))
        print("shimmer_task stop time: "+str(end_time))

        ####-------------------------------------------------------------
        ####-------------------------------------------------------------
        ####-------------------------------------------------------------
    
        start_timestamp_recovery= recovery_onset_list_timestamps[ind_timestamp]
        stop_timestamp_recovery =get_offset_timestamp(start_timestamp_recovery, offset_min)
        sliced_ecg_df_recovery=slice_df_wrt_timestamps(selected_ecg_df, start_timestamp_recovery, stop_timestamp_recovery, shimmer_timestamp_col_name)
        sliced_ecg_df_recovery=sliced_ecg_df_recovery.reset_index(drop=True)

        ###-------------------------------------------------
        ecg_array_recovery = sliced_ecg_df_recovery["ecg"].values
        out_recovery = ecg.ecg(signal=ecg_array_recovery, sampling_rate=sampling_freq_shimmer, show=False, interactive=False)
        sliced_ecg_df_recovery["filtered"] = out_recovery["filtered"]
        r_peaks_ind_recovery = out_recovery["rpeaks"]
        rr_msec_recovery=from_rr_ind_2_msec(r_peaks_ind_recovery)
        rr_msec_recovery_clean=remove_outliers_rri(rr_msec_recovery, sampling_freq = 256, outlier_std = 1.5)
        time_domain_features=timedomain(rr_msec_recovery_clean)
        ###--------------------------------------------------
        mean_hbpm_recovery = time_domain_features["Mean HR (beats/min)"]
        std_hbpm_recovery = time_domain_features["STD HR (beats/min)"]
        ###-----------------------------------------------------
        all_ibi_one_list_one_task.extend(rr_msec_task_clean)
        all_ibi_sublist_one_task.append(rr_msec_task_clean)
        mean_cumm_list.append(np.mean(rr_msec_recovery_clean))
        std_cumm_list.append(np.std(rr_msec_recovery_clean))
        
        mean_hbpm_cumm_list.append(mean_hbpm_recovery)
        std_hbpm_cumm_list.append(std_hbpm_recovery)
        
        
        #####------------------------------------------------------------
        ##### -------------for debugging---------------------------------
        #####------------------------------------------------------------
        start_time = dt.datetime.fromtimestamp(start_timestamp_recovery, tz)
        end_time  = dt.datetime.fromtimestamp(stop_timestamp_recovery, tz)

        print("recovery start time: "+str(start_time))
        print("recovery stop time: "+str(end_time))


        time_stamps_shimmer= sliced_ecg_df_recovery[shimmer_timestamp_col_name].values

        start_timestamp_shimmer = time_stamps_shimmer[0]
        end_timestamp_shimmer =  time_stamps_shimmer[-1]

        start_time = dt.datetime.fromtimestamp(start_timestamp_shimmer, tz)
        end_time  = dt.datetime.fromtimestamp(end_timestamp_shimmer, tz)

        print("shimmer_recovery start time: "+str(start_time))
        print("shimmer_recovery stop time: "+str(end_time))

        ####-------------------------------------------------------------
        ####-------------------------------------------------------------
        ####-------------------------------------------------------------
        
        
        hrv_data_dict = {}
        
        hrv_data_dict["subject_id"] = file_name_ii
        
        event_interets_plot = ["Baseline", "Task", "Recovery"]
    
        hrv_data_dict["event_interst"] = event_interets_plot
    
        hrv_data_dict["all_rr_one_list"] = all_ibi_one_list_one_task
    
        hrv_data_dict["all_rr_sublists"] = all_ibi_sublist_one_task
        
        hrv_data_dict["mean_hbpm"] = mean_hbpm_cumm_list
        hrv_data_dict["std_hbpmy"] = std_hbpm_cumm_list
        
        hrv_data_dict["mean_ibi"] = mean_cumm_list
        hrv_data_dict["std_ibi"] = std_cumm_list
        
        hrv_data_dict["task_type"] = task_type_ii
        
        
        pkl_file_hrv = file_name_trig[:-4] + "_"+task_type_ii+ ".pkl"
        
        print(pkl_file_hrv)
        
        dest_path_pkl_file = os.path.join(dest_path, pkl_file_hrv)
        with open(dest_path_pkl_file, "wb") as f:
            pickle.dump(hrv_data_dict, f)
            f.close()
            
        title_fig =  task_type_ii+ ":" + file_name_trig[:-4]
        fig_name =  file_name_trig[:-4]+ "_" + task_type_ii+".png"
        fig_dest_path = os.path.join(dest_path,fig_name)
        y_label_fig = "HBPM"
        fig_mean_std= plot_mean_std(mean_hbpm_cumm_list, std_hbpm_cumm_list, event_interets_plot, title_fig, y_label_fig)
        
        fig_mean_std.savefig(fig_dest_path)
        
        
        
        #mean_norm_list, std_norm_list = min_max_norm(all_ibi_one_list_one_task, all_ibi_sublist_one_task)
        
        #title_fig =  file_name_ii[:-4] + task_type_ii 
        #y_label_fig = "Norm-IBI"
        #fig_norm_mean_std= plot_mean_std(mean_norm_list, std_norm_list, event_interets_plot, title_fig, y_label_fig)
        
        
        
    
        ###-------------------------------------------------------------------
        ####-------------------for raw and filtered plotting-------------------
        ####-------------------------------------------------------------------
        #print("RECOVERY DATA")
        #fig_name="Recovery_"+ sub_id + ".png"
        #fig_name = "Recovery"+str(ind_timestamp)+".png"
        #plt_title_raw = "Raw ECG: Recovery"
        #plt_title_filtered = "Filtered ECG: Recovery"
        #plot_ecg_wf(sliced_ecg_df_recovery,r_peaks_ind_recovery,offset_min, dest_path_save_figures, 
         #           fig_name, nr_plots=total_plots, fig_title_raw=plt_title_raw, fig_title_filtered=plt_title_filtered )

        ####-------------------------------------------------------------------------
# Out:
# psychopy_events_triggers_WP2_01_IGFW.csv
# pre_assesment
# baseline start time: 2023-09-18 11:18:38.760779+02:00
# baseline stop time: 2023-09-18 11:23:38.760779+02:00
# shimmer_baseline start time: 2023-09-18 11:18:38.761627+02:00
# shimmer_baseline stop time: 2023-09-18 11:23:38.757721+02:00
# task start time: 2023-09-18 11:23:39.040433+02:00
# task stop time: 2023-09-18 11:28:39.040433+02:00
# shimmer_task start time: 2023-09-18 11:23:39.042877+02:00
# shimmer_task stop time: 2023-09-18 11:28:39.038971+02:00
# recovery start time: 2023-09-18 11:28:40.057839+02:00
# recovery stop time: 2023-09-18 11:33:40.057839+02:00
# shimmer_recovery start time: 2023-09-18 11:28:40.058502+02:00
# shimmer_recovery stop time: 2023-09-18 11:33:40.054596+02:00
# psychopy_events_triggers_WP2_01_IGFW_pre_assesment.pkl
# negative
# baseline start time: 2023-09-18 11:34:25.806835+02:00
# baseline stop time: 2023-09-18 11:39:25.806835+02:00
# shimmer_baseline start time: 2023-09-18 11:34:25.808502+02:00
# shimmer_baseline stop time: 2023-09-18 11:39:25.804596+02:00
# task start time: 2023-09-18 11:39:26.194674+02:00
# task stop time: 2023-09-18 11:44:26.194674+02:00
# shimmer_task start time: 2023-09-18 11:39:26.195221+02:00
# shimmer_task stop time: 2023-09-18 11:44:26.191315+02:00
# recovery start time: 2023-09-18 11:44:28.633173+02:00
# recovery stop time: 2023-09-18 11:49:28.633173+02:00
# shimmer_recovery start time: 2023-09-18 11:44:28.636627+02:00
# shimmer_recovery stop time: 2023-09-18 11:49:28.632721+02:00
# psychopy_events_triggers_WP2_01_IGFW_negative.pkl
# positive
# baseline start time: 2023-09-18 11:56:44.448840+02:00
# baseline stop time: 2023-09-18 12:01:44.448840+02:00
# shimmer_baseline start time: 2023-09-18 11:56:44.449127+02:00
# shimmer_baseline stop time: 2023-09-18 12:01:44.445221+02:00
# task start time: 2023-09-18 12:01:44.724144+02:00
# task stop time: 2023-09-18 12:06:44.724144+02:00
# shimmer_task start time: 2023-09-18 12:01:44.726471+02:00
# shimmer_task stop time: 2023-09-18 12:06:44.722565+02:00
# recovery start time: 2023-09-18 12:06:47.946690+02:00
# recovery stop time: 2023-09-18 12:11:47.946690+02:00
# shimmer_recovery start time: 2023-09-18 12:06:47.949127+02:00
# shimmer_recovery stop time: 2023-09-18 12:11:47.945221+02:00
# psychopy_events_triggers_WP2_01_IGFW_positive.pkl
# psychopy_events_triggers_WP2_02_LPJX.csv
# pre_assesment
# baseline start time: 2023-09-18 15:26:31.112198+02:00
# baseline stop time: 2023-09-18 15:31:31.112198+02:00
# shimmer_baseline start time: 2023-09-18 15:26:31.112305+02:00
# shimmer_baseline stop time: 2023-09-18 15:31:31.108398+02:00
# task start time: 2023-09-18 15:31:31.375463+02:00
# task stop time: 2023-09-18 15:36:31.375463+02:00
# shimmer_task start time: 2023-09-18 15:31:31.377930+02:00
# shimmer_task stop time: 2023-09-18 15:36:31.374023+02:00
# recovery start time: 2023-09-18 15:36:32.400266+02:00
# recovery stop time: 2023-09-18 15:41:32.400266+02:00
# shimmer_recovery start time: 2023-09-18 15:36:32.401367+02:00
# shimmer_recovery stop time: 2023-09-18 15:41:32.397461+02:00
# psychopy_events_triggers_WP2_02_LPJX_pre_assesment.pkl
# positive
# baseline start time: 2023-09-18 15:42:25.502627+02:00
# baseline stop time: 2023-09-18 15:47:25.502627+02:00
# shimmer_baseline start time: 2023-09-18 15:42:25.502930+02:00
# shimmer_baseline stop time: 2023-09-18 15:47:25.499023+02:00
# task start time: 2023-09-18 15:47:25.887858+02:00
# task stop time: 2023-09-18 15:52:25.887858+02:00
# shimmer_task start time: 2023-09-18 15:47:25.889648+02:00
# shimmer_task stop time: 2023-09-18 15:52:25.885742+02:00
# recovery start time: 2023-09-18 15:52:27.634107+02:00
# recovery stop time: 2023-09-18 15:57:27.634107+02:00
# shimmer_recovery start time: 2023-09-18 15:52:27.635742+02:00
# shimmer_recovery stop time: 2023-09-18 15:57:27.631836+02:00
# psychopy_events_triggers_WP2_02_LPJX_positive.pkl
# negative
# baseline start time: 2023-09-18 16:04:40.357118+02:00
# baseline stop time: 2023-09-18 16:09:40.357118+02:00
# shimmer_baseline start time: 2023-09-18 16:04:40.358398+02:00
# shimmer_baseline stop time: 2023-09-18 16:09:40.354492+02:00
# task start time: 2023-09-18 16:09:40.764867+02:00
# task stop time: 2023-09-18 16:14:40.764867+02:00
# shimmer_task start time: 2023-09-18 16:09:40.768555+02:00
# shimmer_task stop time: 2023-09-18 16:14:40.764648+02:00
# recovery start time: 2023-09-18 16:14:42.750205+02:00
# recovery stop time: 2023-09-18 16:19:42.750205+02:00
# shimmer_recovery start time: 2023-09-18 16:14:42.752930+02:00
# shimmer_recovery stop time: 2023-09-18 16:19:42.749023+02:00
# psychopy_events_triggers_WP2_02_LPJX_negative.pkl
# psychopy_events_triggers_WP2_04_HYXA.csv
# pre_assesment
# baseline start time: 2023-09-19 15:00:09.343098+02:00
# baseline stop time: 2023-09-19 15:05:09.343098+02:00
# shimmer_baseline start time: 2023-09-19 15:00:09.343658+02:00
# shimmer_baseline stop time: 2023-09-19 15:05:09.339752+02:00
# task start time: 2023-09-19 15:05:09.631776+02:00
# task stop time: 2023-09-19 15:10:09.631776+02:00
# shimmer_task start time: 2023-09-19 15:05:09.632721+02:00
# shimmer_task stop time: 2023-09-19 15:10:09.628815+02:00
# recovery start time: 2023-09-19 15:10:10.646213+02:00
# recovery stop time: 2023-09-19 15:15:10.646213+02:00
# shimmer_recovery start time: 2023-09-19 15:10:10.648346+02:00
# shimmer_recovery stop time: 2023-09-19 15:15:10.644440+02:00
# psychopy_events_triggers_WP2_04_HYXA_pre_assesment.pkl
# negative
# baseline start time: 2023-09-19 15:16:02.780710+02:00
# baseline stop time: 2023-09-19 15:21:02.780710+02:00
# shimmer_baseline start time: 2023-09-19 15:16:02.781158+02:00
# shimmer_baseline stop time: 2023-09-19 15:21:02.777252+02:00
# task start time: 2023-09-19 15:21:03.161959+02:00
# task stop time: 2023-09-19 15:26:03.161959+02:00
# shimmer_task start time: 2023-09-19 15:21:03.163971+02:00
# shimmer_task stop time: 2023-09-19 15:26:03.160065+02:00
# recovery start time: 2023-09-19 15:26:05.720299+02:00
# recovery stop time: 2023-09-19 15:31:05.720299+02:00
# shimmer_recovery start time: 2023-09-19 15:26:05.722565+02:00
# shimmer_recovery stop time: 2023-09-19 15:31:05.718658+02:00
# psychopy_events_triggers_WP2_04_HYXA_negative.pkl
# positive
# baseline start time: 2023-09-19 15:38:40.561193+02:00
# baseline stop time: 2023-09-19 15:43:40.561193+02:00
# shimmer_baseline start time: 2023-09-19 15:38:40.562408+02:00
# shimmer_baseline stop time: 2023-09-19 15:43:40.558502+02:00
# task start time: 2023-09-19 15:43:40.818270+02:00
# task stop time: 2023-09-19 15:48:40.818270+02:00
# shimmer_task start time: 2023-09-19 15:43:40.820221+02:00
# shimmer_task stop time: 2023-09-19 15:48:40.816315+02:00
# recovery start time: 2023-09-19 15:48:42.582151+02:00
# recovery stop time: 2023-09-19 15:53:42.582151+02:00
# shimmer_recovery start time: 2023-09-19 15:48:42.585846+02:00
# shimmer_recovery stop time: 2023-09-19 15:53:42.581940+02:00
# psychopy_events_triggers_WP2_04_HYXA_positive.pkl
# psychopy_events_triggers_WP2_05_TFMI.csv
# pre_assesment
# baseline start time: 2023-09-20 10:02:15.215537+02:00
# baseline stop time: 2023-09-20 10:07:15.215537+02:00
# shimmer_baseline start time: 2023-09-20 10:02:15.217163+02:00
# shimmer_baseline stop time: 2023-09-20 10:07:15.213257+02:00
# task start time: 2023-09-20 10:07:15.486585+02:00
# task stop time: 2023-09-20 10:12:15.486585+02:00
# shimmer_task start time: 2023-09-20 10:07:15.486694+02:00
# shimmer_task stop time: 2023-09-20 10:12:15.482788+02:00
# recovery start time: 2023-09-20 10:12:16.558803+02:00
# recovery stop time: 2023-09-20 10:17:16.558803+02:00
# shimmer_recovery start time: 2023-09-20 10:12:16.560913+02:00
# shimmer_recovery stop time: 2023-09-20 10:17:16.557007+02:00
# psychopy_events_triggers_WP2_05_TFMI_pre_assesment.pkl
# negative
# baseline start time: 2023-09-20 10:18:32.236852+02:00
# baseline stop time: 2023-09-20 10:23:32.236852+02:00
# shimmer_baseline start time: 2023-09-20 10:18:32.240601+02:00
# shimmer_baseline stop time: 2023-09-20 10:23:32.236694+02:00
# task start time: 2023-09-20 10:23:32.618864+02:00
# task stop time: 2023-09-20 10:28:32.618864+02:00
# shimmer_task start time: 2023-09-20 10:23:32.619507+02:00
# shimmer_task stop time: 2023-09-20 10:28:32.615601+02:00
# recovery start time: 2023-09-20 10:28:34.386794+02:00
# recovery stop time: 2023-09-20 10:33:34.386794+02:00
# shimmer_recovery start time: 2023-09-20 10:28:34.389038+02:00
# shimmer_recovery stop time: 2023-09-20 10:33:34.385132+02:00
# psychopy_events_triggers_WP2_05_TFMI_negative.pkl
# positive
# baseline start time: 2023-09-20 10:41:12.300185+02:00
# baseline stop time: 2023-09-20 10:46:12.300185+02:00
# shimmer_baseline start time: 2023-09-20 10:41:12.303101+02:00
# shimmer_baseline stop time: 2023-09-20 10:46:12.299194+02:00
# task start time: 2023-09-20 10:46:12.688371+02:00
# task stop time: 2023-09-20 10:51:12.688371+02:00
# shimmer_task start time: 2023-09-20 10:46:12.689819+02:00
# shimmer_task stop time: 2023-09-20 10:51:12.685913+02:00
# recovery start time: 2023-09-20 10:51:15.292078+02:00
# recovery stop time: 2023-09-20 10:56:15.292078+02:00
# shimmer_recovery start time: 2023-09-20 10:51:15.295288+02:00
# shimmer_recovery stop time: 2023-09-20 10:56:15.291382+02:00
# psychopy_events_triggers_WP2_05_TFMI_positive.pkl
# psychopy_events_triggers_WP2_06_NBZR.csv
# pre_assesment
# baseline start time: 2023-09-20 15:04:10.233377+02:00
# baseline stop time: 2023-09-20 15:09:10.233377+02:00
# shimmer_baseline start time: 2023-09-20 15:04:10.235962+02:00
# shimmer_baseline stop time: 2023-09-20 15:09:10.232056+02:00
# task start time: 2023-09-20 15:09:10.498034+02:00
# task stop time: 2023-09-20 15:14:10.498034+02:00
# shimmer_task start time: 2023-09-20 15:09:10.501587+02:00
# shimmer_task stop time: 2023-09-20 15:14:10.497681+02:00
# recovery start time: 2023-09-20 15:14:11.515454+02:00
# recovery stop time: 2023-09-20 15:19:11.515454+02:00
# shimmer_recovery start time: 2023-09-20 15:14:11.517212+02:00
# shimmer_recovery stop time: 2023-09-20 15:19:11.513306+02:00
# psychopy_events_triggers_WP2_06_NBZR_pre_assesment.pkl
# negative
# baseline start time: 2023-09-20 15:20:04.408230+02:00
# baseline stop time: 2023-09-20 15:25:04.408230+02:00
# shimmer_baseline start time: 2023-09-20 15:20:04.411743+02:00
# shimmer_baseline stop time: 2023-09-20 15:25:04.407837+02:00
# task start time: 2023-09-20 15:25:04.780819+02:00
# task stop time: 2023-09-20 15:30:04.780819+02:00
# shimmer_task start time: 2023-09-20 15:25:04.782837+02:00
# shimmer_task stop time: 2023-09-20 15:30:04.778931+02:00
# recovery start time: 2023-09-20 15:30:07.738537+02:00
# recovery stop time: 2023-09-20 15:35:07.738537+02:00
# shimmer_recovery start time: 2023-09-20 15:30:07.739868+02:00
# shimmer_recovery stop time: 2023-09-20 15:35:07.735962+02:00
# psychopy_events_triggers_WP2_06_NBZR_negative.pkl
# positive
# baseline start time: 2023-09-20 15:42:26.259909+02:00
# baseline stop time: 2023-09-20 15:47:26.259909+02:00
# shimmer_baseline start time: 2023-09-20 15:42:26.263306+02:00
# shimmer_baseline stop time: 2023-09-20 15:47:26.259399+02:00
# task start time: 2023-09-20 15:47:26.532456+02:00
# task stop time: 2023-09-20 15:52:26.532456+02:00
# shimmer_task start time: 2023-09-20 15:47:26.532837+02:00
# shimmer_task stop time: 2023-09-20 15:52:26.528931+02:00
# recovery start time: 2023-09-20 15:52:29.031393+02:00
# recovery stop time: 2023-09-20 15:57:29.031393+02:00
# shimmer_recovery start time: 2023-09-20 15:52:29.032837+02:00
# shimmer_recovery stop time: 2023-09-20 15:57:29.028931+02:00
# psychopy_events_triggers_WP2_06_NBZR_positive.pkl
# psychopy_events_triggers_WP2_07_QOWE.csv
# pre_assesment
# baseline start time: 2023-09-21 15:20:39.034962+02:00
# baseline stop time: 2023-09-21 15:25:39.034962+02:00
# shimmer_baseline start time: 2023-09-21 15:20:39.035828+02:00
# shimmer_baseline stop time: 2023-09-21 15:25:39.031921+02:00
# task start time: 2023-09-21 15:25:39.299968+02:00
# task stop time: 2023-09-21 15:30:39.299968+02:00
# shimmer_task start time: 2023-09-21 15:25:39.301453+02:00
# shimmer_task stop time: 2023-09-21 15:30:39.297546+02:00
# recovery start time: 2023-09-21 15:30:40.419580+02:00
# recovery stop time: 2023-09-21 15:35:40.419580+02:00
# shimmer_recovery start time: 2023-09-21 15:30:40.422546+02:00
# shimmer_recovery stop time: 2023-09-21 15:35:40.418640+02:00
# psychopy_events_triggers_WP2_07_QOWE_pre_assesment.pkl
# negative
# baseline start time: 2023-09-21 15:37:03.745570+02:00
# baseline stop time: 2023-09-21 15:42:03.745570+02:00
# shimmer_baseline start time: 2023-09-21 15:37:03.746765+02:00
# shimmer_baseline stop time: 2023-09-21 15:42:03.742859+02:00
# task start time: 2023-09-21 15:42:04.125556+02:00
# task stop time: 2023-09-21 15:47:04.125556+02:00
# shimmer_task start time: 2023-09-21 15:42:04.125671+02:00
# shimmer_task stop time: 2023-09-21 15:47:04.121765+02:00
# recovery start time: 2023-09-21 15:47:06.593762+02:00
# recovery stop time: 2023-09-21 15:52:06.593762+02:00
# shimmer_recovery start time: 2023-09-21 15:47:06.594421+02:00
# shimmer_recovery stop time: 2023-09-21 15:52:06.590515+02:00
# psychopy_events_triggers_WP2_07_QOWE_negative.pkl
# positive
# baseline start time: 2023-09-21 15:59:48.234750+02:00
# baseline stop time: 2023-09-21 16:04:48.234750+02:00
# shimmer_baseline start time: 2023-09-21 15:59:48.235046+02:00
# shimmer_baseline stop time: 2023-09-21 16:04:48.231140+02:00
# task start time: 2023-09-21 16:04:48.631663+02:00
# task stop time: 2023-09-21 16:09:48.631663+02:00
# shimmer_task start time: 2023-09-21 16:04:48.633484+02:00
# shimmer_task stop time: 2023-09-21 16:09:48.629578+02:00
# recovery start time: 2023-09-21 16:09:50.535753+02:00
# recovery stop time: 2023-09-21 16:14:50.535753+02:00
# shimmer_recovery start time: 2023-09-21 16:09:50.535828+02:00
# shimmer_recovery stop time: 2023-09-21 16:14:50.531921+02:00
# psychopy_events_triggers_WP2_07_QOWE_positive.pkl
# psychopy_events_triggers_WP2_08_URYT.csv
# pre_assesment
# baseline start time: 2023-09-22 11:17:43.275826+02:00
# baseline stop time: 2023-09-22 11:22:43.275826+02:00
# shimmer_baseline start time: 2023-09-22 11:17:43.278503+02:00
# shimmer_baseline stop time: 2023-09-22 11:22:43.274597+02:00
# task start time: 2023-09-22 11:22:43.531594+02:00
# task stop time: 2023-09-22 11:27:43.531594+02:00
# shimmer_task start time: 2023-09-22 11:22:43.532410+02:00
# shimmer_task stop time: 2023-09-22 11:27:43.528503+02:00
# recovery start time: 2023-09-22 11:27:44.532706+02:00
# recovery stop time: 2023-09-22 11:32:44.532706+02:00
# shimmer_recovery start time: 2023-09-22 11:27:44.536316+02:00
# shimmer_recovery stop time: 2023-09-22 11:32:44.532410+02:00
# psychopy_events_triggers_WP2_08_URYT_pre_assesment.pkl
# positive
# baseline start time: 2023-09-22 11:33:47.631118+02:00
# baseline stop time: 2023-09-22 11:38:47.631118+02:00
# shimmer_baseline start time: 2023-09-22 11:33:47.633972+02:00
# shimmer_baseline stop time: 2023-09-22 11:38:47.630066+02:00
# task start time: 2023-09-22 11:38:48.010563+02:00
# task stop time: 2023-09-22 11:43:48.010563+02:00
# shimmer_task start time: 2023-09-22 11:38:48.012878+02:00
# shimmer_task stop time: 2023-09-22 11:43:48.008972+02:00
# recovery start time: 2023-09-22 11:43:50.690998+02:00
# recovery stop time: 2023-09-22 11:48:50.690998+02:00
# shimmer_recovery start time: 2023-09-22 11:43:50.692566+02:00
# shimmer_recovery stop time: 2023-09-22 11:48:50.688660+02:00
# psychopy_events_triggers_WP2_08_URYT_positive.pkl
# negative
# baseline start time: 2023-09-22 11:55:55.305796+02:00
# baseline stop time: 2023-09-22 12:00:55.305796+02:00
# shimmer_baseline start time: 2023-09-22 11:55:55.305847+02:00
# shimmer_baseline stop time: 2023-09-22 12:00:55.301941+02:00
# task start time: 2023-09-22 12:00:55.703943+02:00
# task stop time: 2023-09-22 12:05:55.703943+02:00
# shimmer_task start time: 2023-09-22 12:00:55.704285+02:00
# shimmer_task stop time: 2023-09-22 12:05:55.700378+02:00
# recovery start time: 2023-09-22 12:05:58.481791+02:00
# recovery stop time: 2023-09-22 12:10:58.481791+02:00
# shimmer_recovery start time: 2023-09-22 12:05:58.485535+02:00
# shimmer_recovery stop time: 2023-09-22 12:10:58.481628+02:00
# psychopy_events_triggers_WP2_08_URYT_negative.pkl
# psychopy_events_triggers_WP2_09_ZMDC.csv
# pre_assesment
# baseline start time: 2023-09-22 14:56:56.428041+02:00
# baseline stop time: 2023-09-22 15:01:56.428041+02:00
# shimmer_baseline start time: 2023-09-22 14:56:56.428680+02:00
# shimmer_baseline stop time: 2023-09-22 15:01:56.424774+02:00
# task start time: 2023-09-22 15:01:56.724719+02:00
# task stop time: 2023-09-22 15:06:56.724719+02:00
# shimmer_task start time: 2023-09-22 15:01:56.725555+02:00
# shimmer_task stop time: 2023-09-22 15:06:56.721649+02:00
# recovery start time: 2023-09-22 15:06:57.726288+02:00
# recovery stop time: 2023-09-22 15:11:57.726288+02:00
# shimmer_recovery start time: 2023-09-22 15:06:57.729462+02:00
# shimmer_recovery stop time: 2023-09-22 15:11:57.725555+02:00
# psychopy_events_triggers_WP2_09_ZMDC_pre_assesment.pkl
# positive
# baseline start time: 2023-09-22 15:12:34.073087+02:00
# baseline stop time: 2023-09-22 15:17:34.073087+02:00
# shimmer_baseline start time: 2023-09-22 15:12:34.073212+02:00
# shimmer_baseline stop time: 2023-09-22 15:17:34.069305+02:00
# task start time: 2023-09-22 15:17:34.471499+02:00
# task stop time: 2023-09-22 15:22:34.471499+02:00
# shimmer_task start time: 2023-09-22 15:17:34.471649+02:00
# shimmer_task stop time: 2023-09-22 15:22:34.467743+02:00
# recovery start time: 2023-09-22 15:22:36.577988+02:00
# recovery stop time: 2023-09-22 15:27:36.577988+02:00
# shimmer_recovery start time: 2023-09-22 15:22:36.581024+02:00
# shimmer_recovery stop time: 2023-09-22 15:27:36.577118+02:00
# psychopy_events_triggers_WP2_09_ZMDC_positive.pkl
# negative
# baseline start time: 2023-09-22 15:34:48.485154+02:00
# baseline stop time: 2023-09-22 15:39:48.485154+02:00
# shimmer_baseline start time: 2023-09-22 15:34:48.487274+02:00
# shimmer_baseline stop time: 2023-09-22 15:39:48.483368+02:00
# task start time: 2023-09-22 15:39:48.767088+02:00
# task stop time: 2023-09-22 15:44:48.767088+02:00
# shimmer_task start time: 2023-09-22 15:39:48.768524+02:00
# shimmer_task stop time: 2023-09-22 15:44:48.764618+02:00
# recovery start time: 2023-09-22 15:44:50.525349+02:00
# recovery stop time: 2023-09-22 15:49:50.525349+02:00
# shimmer_recovery start time: 2023-09-22 15:44:50.526337+02:00
# shimmer_recovery stop time: 2023-09-22 15:49:50.522430+02:00
# psychopy_events_triggers_WP2_09_ZMDC_negative.pkl
# psychopy_events_triggers_WP2_11_HJVN.csv
# pre_assesment
# baseline start time: 2023-09-25 15:08:19.615264+02:00
# baseline stop time: 2023-09-25 15:13:19.615264+02:00
# shimmer_baseline start time: 2023-09-25 15:08:19.615295+02:00
# shimmer_baseline stop time: 2023-09-25 15:13:19.611389+02:00
# task start time: 2023-09-25 15:13:19.883949+02:00
# task stop time: 2023-09-25 15:18:19.883949+02:00
# shimmer_task start time: 2023-09-25 15:13:19.884827+02:00
# shimmer_task stop time: 2023-09-25 15:18:19.880920+02:00
# recovery start time: 2023-09-25 15:18:21.477783+02:00
# recovery stop time: 2023-09-25 15:23:21.477783+02:00
# shimmer_recovery start time: 2023-09-25 15:18:21.478577+02:00
# shimmer_recovery stop time: 2023-09-25 15:23:21.474670+02:00
# psychopy_events_triggers_WP2_11_HJVN_pre_assesment.pkl
# negative
# baseline start time: 2023-09-25 15:24:35.859131+02:00
# baseline stop time: 2023-09-25 15:29:35.859131+02:00
# shimmer_baseline start time: 2023-09-25 15:24:35.861389+02:00
# shimmer_baseline stop time: 2023-09-25 15:29:35.857483+02:00
# task start time: 2023-09-25 15:29:36.230012+02:00
# task stop time: 2023-09-25 15:34:36.230012+02:00
# shimmer_task start time: 2023-09-25 15:29:36.232483+02:00
# shimmer_task stop time: 2023-09-25 15:34:36.228577+02:00
# recovery start time: 2023-09-25 15:34:37.981966+02:00
# recovery stop time: 2023-09-25 15:39:37.981966+02:00
# shimmer_recovery start time: 2023-09-25 15:34:37.982483+02:00
# shimmer_recovery stop time: 2023-09-25 15:39:37.978577+02:00
# psychopy_events_triggers_WP2_11_HJVN_negative.pkl
# positive
# baseline start time: 2023-09-25 15:47:12.260191+02:00
# baseline stop time: 2023-09-25 15:52:12.260191+02:00
# shimmer_baseline start time: 2023-09-25 15:47:12.263733+02:00
# shimmer_baseline stop time: 2023-09-25 15:52:12.259827+02:00
# task start time: 2023-09-25 15:52:12.506649+02:00
# task stop time: 2023-09-25 15:57:12.506649+02:00
# shimmer_task start time: 2023-09-25 15:52:12.509827+02:00
# shimmer_task stop time: 2023-09-25 15:57:12.505920+02:00
# recovery start time: 2023-09-25 15:57:14.262657+02:00
# recovery stop time: 2023-09-25 16:02:14.262657+02:00
# shimmer_recovery start time: 2023-09-25 15:57:14.263733+02:00
# shimmer_recovery stop time: 2023-09-25 16:02:14.259827+02:00
# psychopy_events_triggers_WP2_11_HJVN_positive.pkl
# psychopy_events_triggers_WP2_12_UIAG.csv
# pre_assesment
# baseline start time: 2023-09-26 12:12:01.127517+02:00
# baseline stop time: 2023-09-26 12:17:01.127517+02:00
# shimmer_baseline start time: 2023-09-26 12:12:01.129486+02:00
# shimmer_baseline stop time: 2023-09-26 12:17:01.125580+02:00
# task start time: 2023-09-26 12:17:01.397935+02:00
# task stop time: 2023-09-26 12:22:01.397935+02:00
# shimmer_task start time: 2023-09-26 12:17:01.399017+02:00
# shimmer_task stop time: 2023-09-26 12:22:01.395111+02:00
# recovery start time: 2023-09-26 12:22:02.945310+02:00
# recovery stop time: 2023-09-26 12:27:02.945310+02:00
# shimmer_recovery start time: 2023-09-26 12:22:02.945892+02:00
# shimmer_recovery stop time: 2023-09-26 12:27:02.941986+02:00
# psychopy_events_triggers_WP2_12_UIAG_pre_assesment.pkl
# negative
# baseline start time: 2023-09-26 12:27:49.003350+02:00
# baseline stop time: 2023-09-26 12:32:49.003350+02:00
# shimmer_baseline start time: 2023-09-26 12:27:49.004486+02:00
# shimmer_baseline stop time: 2023-09-26 12:32:49.000580+02:00
# task start time: 2023-09-26 12:32:49.376188+02:00
# task stop time: 2023-09-26 12:37:49.376188+02:00
# shimmer_task start time: 2023-09-26 12:32:49.379486+02:00
# shimmer_task stop time: 2023-09-26 12:37:49.375580+02:00
# recovery start time: 2023-09-26 12:37:51.116492+02:00
# recovery stop time: 2023-09-26 12:42:51.116492+02:00
# shimmer_recovery start time: 2023-09-26 12:37:51.117767+02:00
# shimmer_recovery stop time: 2023-09-26 12:42:51.113861+02:00
# psychopy_events_triggers_WP2_12_UIAG_negative.pkl
# positive
# baseline start time: 2023-09-26 12:50:16.578110+02:00
# baseline stop time: 2023-09-26 12:55:16.578110+02:00
# shimmer_baseline start time: 2023-09-26 12:50:16.578705+02:00
# shimmer_baseline stop time: 2023-09-26 12:55:16.574799+02:00
# task start time: 2023-09-26 12:55:16.879713+02:00
# task stop time: 2023-09-26 13:00:16.879713+02:00
# shimmer_task start time: 2023-09-26 12:55:16.883392+02:00
# shimmer_task stop time: 2023-09-26 13:00:16.879486+02:00
# recovery start time: 2023-09-26 13:00:18.638765+02:00
# recovery stop time: 2023-09-26 13:05:18.638765+02:00
# shimmer_recovery start time: 2023-09-26 13:00:18.641205+02:00
# shimmer_recovery stop time: 2023-09-26 13:05:18.637299+02:00
# psychopy_events_triggers_WP2_12_UIAG_positive.pkl
# psychopy_events_triggers_WP2_13_LYOT.csv
# pre_assesment
# baseline start time: 2023-09-26 15:27:45.294055+02:00
# baseline stop time: 2023-09-26 15:32:45.294055+02:00
# shimmer_baseline start time: 2023-09-26 15:27:45.295319+02:00
# shimmer_baseline stop time: 2023-09-26 15:32:45.291412+02:00
# task start time: 2023-09-26 15:32:45.649329+02:00
# task stop time: 2023-09-26 15:37:45.649329+02:00
# shimmer_task start time: 2023-09-26 15:32:45.650787+02:00
# shimmer_task stop time: 2023-09-26 15:37:45.646881+02:00
# recovery start time: 2023-09-26 15:37:46.659218+02:00
# recovery stop time: 2023-09-26 15:42:46.659218+02:00
# shimmer_recovery start time: 2023-09-26 15:37:46.662506+02:00
# shimmer_recovery stop time: 2023-09-26 15:42:46.658600+02:00
# psychopy_events_triggers_WP2_13_LYOT_pre_assesment.pkl
# negative
# baseline start time: 2023-09-26 15:44:00.288244+02:00
# baseline stop time: 2023-09-26 15:49:00.288244+02:00
# shimmer_baseline start time: 2023-09-26 15:44:00.291412+02:00
# shimmer_baseline stop time: 2023-09-26 15:49:00.287506+02:00
# task start time: 2023-09-26 15:49:00.661363+02:00
# task stop time: 2023-09-26 15:54:00.661363+02:00
# shimmer_task start time: 2023-09-26 15:49:00.662506+02:00
# shimmer_task stop time: 2023-09-26 15:54:00.658600+02:00
# recovery start time: 2023-09-26 15:54:02.415955+02:00
# recovery stop time: 2023-09-26 15:59:02.415955+02:00
# shimmer_recovery start time: 2023-09-26 15:54:02.416412+02:00
# shimmer_recovery stop time: 2023-09-26 15:59:02.412506+02:00
# psychopy_events_triggers_WP2_13_LYOT_negative.pkl
# positive
# baseline start time: 2023-09-26 16:06:43.346950+02:00
# baseline stop time: 2023-09-26 16:11:43.346950+02:00
# shimmer_baseline start time: 2023-09-26 16:06:43.350006+02:00
# shimmer_baseline stop time: 2023-09-26 16:11:43.346100+02:00
# task start time: 2023-09-26 16:11:43.599222+02:00
# task stop time: 2023-09-26 16:16:43.599222+02:00
# shimmer_task start time: 2023-09-26 16:11:43.600006+02:00
# shimmer_task stop time: 2023-09-26 16:16:43.596100+02:00
# recovery start time: 2023-09-26 16:16:45.364591+02:00
# recovery stop time: 2023-09-26 16:21:45.364591+02:00
# shimmer_recovery start time: 2023-09-26 16:16:45.365631+02:00
# shimmer_recovery stop time: 2023-09-26 16:21:45.361725+02:00
# psychopy_events_triggers_WP2_13_LYOT_positive.pkl
# psychopy_events_triggers_WP2_14_AUNB.csv
# pre_assesment
# baseline start time: 2023-09-27 14:58:27.508259+02:00
# baseline stop time: 2023-09-27 15:03:27.508259+02:00
# shimmer_baseline start time: 2023-09-27 14:58:27.511169+02:00
# shimmer_baseline stop time: 2023-09-27 15:03:27.507263+02:00
# task start time: 2023-09-27 15:03:27.781507+02:00
# task stop time: 2023-09-27 15:08:27.781507+02:00
# shimmer_task start time: 2023-09-27 15:03:27.784607+02:00
# shimmer_task stop time: 2023-09-27 15:08:27.780701+02:00
# recovery start time: 2023-09-27 15:08:28.795155+02:00
# recovery stop time: 2023-09-27 15:13:28.795155+02:00
# shimmer_recovery start time: 2023-09-27 15:08:28.796326+02:00
# shimmer_recovery stop time: 2023-09-27 15:13:28.792419+02:00
# psychopy_events_triggers_WP2_14_AUNB_pre_assesment.pkl
# negative
# baseline start time: 2023-09-27 15:14:12.523806+02:00
# baseline stop time: 2023-09-27 15:19:12.523806+02:00
# shimmer_baseline start time: 2023-09-27 15:14:12.526794+02:00
# shimmer_baseline stop time: 2023-09-27 15:19:12.522888+02:00
# task start time: 2023-09-27 15:19:12.899661+02:00
# task stop time: 2023-09-27 15:24:12.899661+02:00
# shimmer_task start time: 2023-09-27 15:19:12.901794+02:00
# shimmer_task stop time: 2023-09-27 15:24:12.897888+02:00
# recovery start time: 2023-09-27 15:24:14.659223+02:00
# recovery stop time: 2023-09-27 15:29:14.659223+02:00
# shimmer_recovery start time: 2023-09-27 15:24:14.659607+02:00
# shimmer_recovery stop time: 2023-09-27 15:29:14.655701+02:00
# psychopy_events_triggers_WP2_14_AUNB_negative.pkl
# positive
# baseline start time: 2023-09-27 15:36:29.320263+02:00
# baseline stop time: 2023-09-27 15:41:29.320263+02:00
# shimmer_baseline start time: 2023-09-27 15:36:29.323669+02:00
# shimmer_baseline stop time: 2023-09-27 15:41:29.319763+02:00
# task start time: 2023-09-27 15:41:29.712545+02:00
# task stop time: 2023-09-27 15:46:29.712545+02:00
# shimmer_task start time: 2023-09-27 15:41:29.714294+02:00
# shimmer_task stop time: 2023-09-27 15:46:29.710388+02:00
# recovery start time: 2023-09-27 15:46:31.472094+02:00
# recovery stop time: 2023-09-27 15:51:31.472094+02:00
# shimmer_recovery start time: 2023-09-27 15:46:31.472107+02:00
# shimmer_recovery stop time: 2023-09-27 15:51:31.468201+02:00
# psychopy_events_triggers_WP2_14_AUNB_positive.pkl
# psychopy_events_triggers_WP2_15_RMIV.csv
# pre_assesment
# baseline start time: 2023-09-28 15:06:09.813591+02:00
# baseline stop time: 2023-09-28 15:11:09.813591+02:00
# shimmer_baseline start time: 2023-09-28 15:06:09.816467+02:00
# shimmer_baseline stop time: 2023-09-28 15:11:09.812561+02:00
# task start time: 2023-09-28 15:11:10.109681+02:00
# task stop time: 2023-09-28 15:16:10.109681+02:00
# shimmer_task start time: 2023-09-28 15:11:10.113342+02:00
# shimmer_task stop time: 2023-09-28 15:16:10.109436+02:00
# recovery start time: 2023-09-28 15:16:11.121927+02:00
# recovery stop time: 2023-09-28 15:21:11.121927+02:00
# shimmer_recovery start time: 2023-09-28 15:16:11.125061+02:00
# shimmer_recovery stop time: 2023-09-28 15:21:11.121155+02:00
# psychopy_events_triggers_WP2_15_RMIV_pre_assesment.pkl
# negative
# baseline start time: 2023-09-28 15:22:15.404934+02:00
# baseline stop time: 2023-09-28 15:27:15.404934+02:00
# shimmer_baseline start time: 2023-09-28 15:22:15.406311+02:00
# shimmer_baseline stop time: 2023-09-28 15:27:15.402405+02:00
# task start time: 2023-09-28 15:27:15.804569+02:00
# task stop time: 2023-09-28 15:32:15.804569+02:00
# shimmer_task start time: 2023-09-28 15:27:15.804749+02:00
# shimmer_task stop time: 2023-09-28 15:32:15.800842+02:00
# recovery start time: 2023-09-28 15:32:17.754539+02:00
# recovery stop time: 2023-09-28 15:37:17.754539+02:00
# shimmer_recovery start time: 2023-09-28 15:32:17.757874+02:00
# shimmer_recovery stop time: 2023-09-28 15:37:17.753967+02:00
# psychopy_events_triggers_WP2_15_RMIV_negative.pkl
# positive
# baseline start time: 2023-09-28 15:44:56.445868+02:00
# baseline stop time: 2023-09-28 15:49:56.445868+02:00
# shimmer_baseline start time: 2023-09-28 15:44:56.449280+02:00
# shimmer_baseline stop time: 2023-09-28 15:49:56.445374+02:00
# task start time: 2023-09-28 15:49:56.852134+02:00
# task stop time: 2023-09-28 15:54:56.852134+02:00
# shimmer_task start time: 2023-09-28 15:49:56.855530+02:00
# shimmer_task stop time: 2023-09-28 15:54:56.851624+02:00
# recovery start time: 2023-09-28 15:54:58.612065+02:00
# recovery stop time: 2023-09-28 15:59:58.612065+02:00
# shimmer_recovery start time: 2023-09-28 15:54:58.613342+02:00
# shimmer_recovery stop time: 2023-09-28 15:59:58.609436+02:00
# psychopy_events_triggers_WP2_15_RMIV_positive.pkl
# psychopy_events_triggers_WP2_16_DPFK.csv
# pre_assesment
# baseline start time: 2023-09-29 15:19:51.757781+02:00
# baseline stop time: 2023-09-29 15:24:51.757781+02:00
# shimmer_baseline start time: 2023-09-29 15:19:51.760132+02:00
# shimmer_baseline stop time: 2023-09-29 15:24:51.756226+02:00
# task start time: 2023-09-29 15:24:52.174416+02:00
# task stop time: 2023-09-29 15:29:52.174416+02:00
# shimmer_task start time: 2023-09-29 15:24:52.178101+02:00
# shimmer_task stop time: 2023-09-29 15:29:52.174194+02:00
# recovery start time: 2023-09-29 15:29:53.182614+02:00
# recovery stop time: 2023-09-29 15:34:53.182614+02:00
# shimmer_recovery start time: 2023-09-29 15:29:53.185913+02:00
# shimmer_recovery stop time: 2023-09-29 15:34:53.182007+02:00
# psychopy_events_triggers_WP2_16_DPFK_pre_assesment.pkl
# positive
# baseline start time: 2023-09-29 15:35:26.930487+02:00
# baseline stop time: 2023-09-29 15:40:26.930487+02:00
# shimmer_baseline start time: 2023-09-29 15:35:26.932007+02:00
# shimmer_baseline stop time: 2023-09-29 15:40:26.928101+02:00
# task start time: 2023-09-29 15:40:27.336558+02:00
# task stop time: 2023-09-29 15:45:27.336558+02:00
# shimmer_task start time: 2023-09-29 15:40:27.338257+02:00
# shimmer_task stop time: 2023-09-29 15:45:27.334351+02:00
# recovery start time: 2023-09-29 15:45:29.105158+02:00
# recovery stop time: 2023-09-29 15:50:29.105158+02:00
# shimmer_recovery start time: 2023-09-29 15:45:29.107788+02:00
# shimmer_recovery stop time: 2023-09-29 15:50:29.103882+02:00
# psychopy_events_triggers_WP2_16_DPFK_positive.pkl
# negative
# baseline start time: 2023-09-29 15:57:23.386230+02:00
# baseline stop time: 2023-09-29 16:02:23.386230+02:00
# shimmer_baseline start time: 2023-09-29 15:57:23.389038+02:00
# shimmer_baseline stop time: 2023-09-29 16:02:23.385132+02:00
# task start time: 2023-09-29 16:02:23.690649+02:00
# task stop time: 2023-09-29 16:07:23.690649+02:00
# shimmer_task start time: 2023-09-29 16:02:23.693726+02:00
# shimmer_task stop time: 2023-09-29 16:07:23.689819+02:00
# recovery start time: 2023-09-29 16:07:26.232121+02:00
# recovery stop time: 2023-09-29 16:12:26.232121+02:00
# shimmer_recovery start time: 2023-09-29 16:07:26.232788+02:00
# shimmer_recovery stop time: 2023-09-29 16:12:26.228882+02:00
# psychopy_events_triggers_WP2_16_DPFK_negative.pkl
# psychopy_events_triggers_WP2_17_VWOK.csv
# pre_assesment
# baseline start time: 2023-10-02 11:04:15.797570+02:00
# baseline stop time: 2023-10-02 11:09:15.797570+02:00
# shimmer_baseline start time: 2023-10-02 11:04:15.799103+02:00
# shimmer_baseline stop time: 2023-10-02 11:09:15.795197+02:00
# task start time: 2023-10-02 11:09:16.099899+02:00
# task stop time: 2023-10-02 11:14:16.099899+02:00
# shimmer_task start time: 2023-10-02 11:09:16.103790+02:00
# shimmer_task stop time: 2023-10-02 11:14:16.099884+02:00
# recovery start time: 2023-10-02 11:14:17.816789+02:00
# recovery stop time: 2023-10-02 11:19:17.816789+02:00
# shimmer_recovery start time: 2023-10-02 11:14:17.818634+02:00
# shimmer_recovery stop time: 2023-10-02 11:19:17.814728+02:00
# psychopy_events_triggers_WP2_17_VWOK_pre_assesment.pkl
# positive
# baseline start time: 2023-10-02 11:20:22.742640+02:00
# baseline stop time: 2023-10-02 11:25:22.742640+02:00
# shimmer_baseline start time: 2023-10-02 11:20:22.744415+02:00
# shimmer_baseline stop time: 2023-10-02 11:25:22.740509+02:00
# task start time: 2023-10-02 11:25:23.152406+02:00
# task stop time: 2023-10-02 11:30:23.152406+02:00
# shimmer_task start time: 2023-10-02 11:25:23.154572+02:00
# shimmer_task stop time: 2023-10-02 11:30:23.150665+02:00
# recovery start time: 2023-10-02 11:30:24.912624+02:00
# recovery stop time: 2023-10-02 11:35:24.912624+02:00
# shimmer_recovery start time: 2023-10-02 11:30:24.916290+02:00
# shimmer_recovery stop time: 2023-10-02 11:35:24.912384+02:00
# psychopy_events_triggers_WP2_17_VWOK_positive.pkl
# negative
# baseline start time: 2023-10-02 11:42:44.960570+02:00
# baseline stop time: 2023-10-02 11:47:44.960570+02:00
# shimmer_baseline start time: 2023-10-02 11:42:44.963165+02:00
# shimmer_baseline stop time: 2023-10-02 11:47:44.959259+02:00
# task start time: 2023-10-02 11:47:45.324542+02:00
# task stop time: 2023-10-02 11:52:45.324542+02:00
# shimmer_task start time: 2023-10-02 11:47:45.326447+02:00
# shimmer_task stop time: 2023-10-02 11:52:45.322540+02:00
# recovery start time: 2023-10-02 11:52:48.481319+02:00
# recovery stop time: 2023-10-02 11:57:48.481319+02:00
# shimmer_recovery start time: 2023-10-02 11:52:48.482697+02:00
# shimmer_recovery stop time: 2023-10-02 11:57:48.478790+02:00
# psychopy_events_triggers_WP2_17_VWOK_negative.pkl
# psychopy_events_triggers_WP2_18_TUEI.csv
# pre_assesment
# baseline start time: 2023-10-02 15:11:05.161143+02:00
# baseline stop time: 2023-10-02 15:16:05.161143+02:00
# shimmer_baseline start time: 2023-10-02 15:11:05.164764+02:00
# shimmer_baseline stop time: 2023-10-02 15:16:05.160858+02:00
# task start time: 2023-10-02 15:16:05.463524+02:00
# task stop time: 2023-10-02 15:21:05.463524+02:00
# shimmer_task start time: 2023-10-02 15:16:05.465546+02:00
# shimmer_task stop time: 2023-10-02 15:21:05.461639+02:00
# recovery start time: 2023-10-02 15:21:06.473798+02:00
# recovery stop time: 2023-10-02 15:26:06.473798+02:00
# shimmer_recovery start time: 2023-10-02 15:21:06.477264+02:00
# shimmer_recovery stop time: 2023-10-02 15:26:06.473358+02:00
# psychopy_events_triggers_WP2_18_TUEI_pre_assesment.pkl
# positive
# baseline start time: 2023-10-02 15:27:21.212652+02:00
# baseline stop time: 2023-10-02 15:32:21.212652+02:00
# shimmer_baseline start time: 2023-10-02 15:27:21.215546+02:00
# shimmer_baseline stop time: 2023-10-02 15:32:21.211639+02:00
# task start time: 2023-10-02 15:32:21.621837+02:00
# task stop time: 2023-10-02 15:37:21.621837+02:00
# shimmer_task start time: 2023-10-02 15:32:21.625702+02:00
# shimmer_task stop time: 2023-10-02 15:37:21.621796+02:00
# recovery start time: 2023-10-02 15:37:24.876676+02:00
# recovery stop time: 2023-10-02 15:42:24.876676+02:00
# shimmer_recovery start time: 2023-10-02 15:37:24.879608+02:00
# shimmer_recovery stop time: 2023-10-02 15:42:24.875702+02:00
# psychopy_events_triggers_WP2_18_TUEI_positive.pkl
# negative
# baseline start time: 2023-10-02 15:49:45.444055+02:00
# baseline stop time: 2023-10-02 15:54:45.444055+02:00
# shimmer_baseline start time: 2023-10-02 15:49:45.446014+02:00
# shimmer_baseline stop time: 2023-10-02 15:54:45.442108+02:00
# task start time: 2023-10-02 15:54:45.751655+02:00
# task stop time: 2023-10-02 15:59:45.751655+02:00
# shimmer_task start time: 2023-10-02 15:54:45.754608+02:00
# shimmer_task stop time: 2023-10-02 15:59:45.750702+02:00
# recovery start time: 2023-10-02 15:59:48.349534+02:00
# recovery stop time: 2023-10-02 16:04:48.349534+02:00
# shimmer_recovery start time: 2023-10-02 15:59:48.352264+02:00
# shimmer_recovery stop time: 2023-10-02 16:04:48.348358+02:00
# psychopy_events_triggers_WP2_18_TUEI_negative.pkl
# psychopy_events_triggers_WP2_19_XOCB.csv
# pre_assesment
# baseline start time: 2023-10-04 11:00:54.595206+02:00
# baseline stop time: 2023-10-04 11:05:54.595206+02:00
# shimmer_baseline start time: 2023-10-04 11:00:54.599091+02:00
# shimmer_baseline stop time: 2023-10-04 11:05:54.595184+02:00
# task start time: 2023-10-04 11:05:54.899420+02:00
# task stop time: 2023-10-04 11:10:54.899420+02:00
# shimmer_task start time: 2023-10-04 11:05:54.899872+02:00
# shimmer_task stop time: 2023-10-04 11:10:54.895966+02:00
# recovery start time: 2023-10-04 11:10:55.905271+02:00
# recovery stop time: 2023-10-04 11:15:55.905271+02:00
# shimmer_recovery start time: 2023-10-04 11:10:55.907684+02:00
# shimmer_recovery stop time: 2023-10-04 11:15:55.903778+02:00
# psychopy_events_triggers_WP2_19_XOCB_pre_assesment.pkl
# negative
# baseline start time: 2023-10-04 11:16:51.392461+02:00
# baseline stop time: 2023-10-04 11:21:51.392461+02:00
# shimmer_baseline start time: 2023-10-04 11:16:51.395966+02:00
# shimmer_baseline stop time: 2023-10-04 11:21:51.392059+02:00
# task start time: 2023-10-04 11:21:51.791344+02:00
# task stop time: 2023-10-04 11:26:51.791344+02:00
# shimmer_task start time: 2023-10-04 11:21:51.794403+02:00
# shimmer_task stop time: 2023-10-04 11:26:51.790497+02:00
# recovery start time: 2023-10-04 11:26:54.018397+02:00
# recovery stop time: 2023-10-04 11:31:54.018397+02:00
# shimmer_recovery start time: 2023-10-04 11:26:54.020966+02:00
# shimmer_recovery stop time: 2023-10-04 11:31:54.017059+02:00
# psychopy_events_triggers_WP2_19_XOCB_negative.pkl
# positive
# baseline start time: 2023-10-04 11:39:25.147326+02:00
# baseline stop time: 2023-10-04 11:44:25.147326+02:00
# shimmer_baseline start time: 2023-10-04 11:39:25.149872+02:00
# shimmer_baseline stop time: 2023-10-04 11:44:25.145966+02:00
# task start time: 2023-10-04 11:44:25.462404+02:00
# task stop time: 2023-10-04 11:49:25.462404+02:00
# shimmer_task start time: 2023-10-04 11:44:25.466278+02:00
# shimmer_task stop time: 2023-10-04 11:49:25.462372+02:00
# recovery start time: 2023-10-04 11:49:27.212995+02:00
# recovery stop time: 2023-10-04 11:54:27.212995+02:00
# shimmer_recovery start time: 2023-10-04 11:49:27.216278+02:00
# shimmer_recovery stop time: 2023-10-04 11:54:27.212372+02:00
# psychopy_events_triggers_WP2_19_XOCB_positive.pkl
# psychopy_events_triggers_WP2_20_ZFYD.csv
# pre_assesment
# baseline start time: 2023-10-04 14:20:34.240255+02:00
# baseline stop time: 2023-10-04 14:25:34.240255+02:00
# shimmer_baseline start time: 2023-10-04 14:20:34.244141+02:00
# shimmer_baseline stop time: 2023-10-04 14:25:34.240234+02:00
# task start time: 2023-10-04 14:25:34.543384+02:00
# task stop time: 2023-10-04 14:30:34.543384+02:00
# shimmer_task start time: 2023-10-04 14:25:34.544922+02:00
# shimmer_task stop time: 2023-10-04 14:30:34.541016+02:00
# recovery start time: 2023-10-04 14:30:35.547459+02:00
# recovery stop time: 2023-10-04 14:35:35.547459+02:00
# shimmer_recovery start time: 2023-10-04 14:30:35.548828+02:00
# shimmer_recovery stop time: 2023-10-04 14:35:35.544922+02:00
# psychopy_events_triggers_WP2_20_ZFYD_pre_assesment.pkl
# negative
# baseline start time: 2023-10-04 14:36:59.677443+02:00
# baseline stop time: 2023-10-04 14:41:59.677443+02:00
# shimmer_baseline start time: 2023-10-04 14:36:59.677734+02:00
# shimmer_baseline stop time: 2023-10-04 14:41:59.673828+02:00
# task start time: 2023-10-04 14:42:00.084480+02:00
# task stop time: 2023-10-04 14:47:00.084480+02:00
# shimmer_task start time: 2023-10-04 14:42:00.087891+02:00
# shimmer_task stop time: 2023-10-04 14:47:00.083984+02:00
# recovery start time: 2023-10-04 14:47:01.835626+02:00
# recovery stop time: 2023-10-04 14:52:01.835626+02:00
# shimmer_recovery start time: 2023-10-04 14:47:01.837891+02:00
# shimmer_recovery stop time: 2023-10-04 14:52:01.833984+02:00
# psychopy_events_triggers_WP2_20_ZFYD_negative.pkl
# positive
# baseline start time: 2023-10-04 14:59:58.416709+02:00
# baseline stop time: 2023-10-04 15:04:58.416709+02:00
# shimmer_baseline start time: 2023-10-04 14:59:58.419922+02:00
# shimmer_baseline stop time: 2023-10-04 15:04:58.416016+02:00
# task start time: 2023-10-04 15:04:58.718087+02:00
# task stop time: 2023-10-04 15:09:58.718087+02:00
# shimmer_task start time: 2023-10-04 15:04:58.720703+02:00
# shimmer_task stop time: 2023-10-04 15:09:58.716797+02:00
# recovery start time: 2023-10-04 15:10:01.463390+02:00
# recovery stop time: 2023-10-04 15:15:01.463390+02:00
# shimmer_recovery start time: 2023-10-04 15:10:01.466797+02:00
# shimmer_recovery stop time: 2023-10-04 15:15:01.462891+02:00
# psychopy_events_triggers_WP2_20_ZFYD_positive.pkl
# psychopy_events_triggers_WP2_21_KBAT.csv
# pre_assesment
# baseline start time: 2023-10-13 11:06:41.062395+02:00
# baseline stop time: 2023-10-13 11:11:41.062395+02:00
# shimmer_baseline start time: 2023-10-13 11:06:41.065826+02:00
# shimmer_baseline stop time: 2023-10-13 11:11:41.061920+02:00
# task start time: 2023-10-13 11:11:41.359850+02:00
# task stop time: 2023-10-13 11:16:41.359850+02:00
# shimmer_task start time: 2023-10-13 11:11:41.362701+02:00
# shimmer_task stop time: 2023-10-13 11:16:41.358795+02:00
# recovery start time: 2023-10-13 11:16:42.363378+02:00
# recovery stop time: 2023-10-13 11:21:42.363378+02:00
# shimmer_recovery start time: 2023-10-13 11:16:42.366608+02:00
# shimmer_recovery stop time: 2023-10-13 11:21:42.362701+02:00
# psychopy_events_triggers_WP2_21_KBAT_pre_assesment.pkl
# positive
# baseline start time: 2023-10-13 11:22:56.382002+02:00
# baseline stop time: 2023-10-13 11:27:56.382002+02:00
# shimmer_baseline start time: 2023-10-13 11:22:56.382233+02:00
# shimmer_baseline stop time: 2023-10-13 11:27:56.378326+02:00
# task start time: 2023-10-13 11:27:56.777334+02:00
# task stop time: 2023-10-13 11:32:56.777334+02:00
# shimmer_task start time: 2023-10-13 11:27:56.780670+02:00
# shimmer_task stop time: 2023-10-13 11:32:56.776764+02:00
# recovery start time: 2023-10-13 11:32:59.704889+02:00
# recovery stop time: 2023-10-13 11:37:59.704889+02:00
# shimmer_recovery start time: 2023-10-13 11:32:59.706451+02:00
# shimmer_recovery stop time: 2023-10-13 11:37:59.702545+02:00
# psychopy_events_triggers_WP2_21_KBAT_positive.pkl
# negative
# baseline start time: 2023-10-13 11:45:25.692340+02:00
# baseline stop time: 2023-10-13 11:50:25.692340+02:00
# shimmer_baseline start time: 2023-10-13 11:45:25.694733+02:00
# shimmer_baseline stop time: 2023-10-13 11:50:25.690826+02:00
# task start time: 2023-10-13 11:50:26.110845+02:00
# task stop time: 2023-10-13 11:55:26.110845+02:00
# shimmer_task start time: 2023-10-13 11:50:26.112701+02:00
# shimmer_task stop time: 2023-10-13 11:55:26.108795+02:00
# recovery start time: 2023-10-13 11:55:29.262831+02:00
# recovery stop time: 2023-10-13 12:00:29.262831+02:00
# shimmer_recovery start time: 2023-10-13 11:55:29.265045+02:00
# shimmer_recovery stop time: 2023-10-13 12:00:29.261139+02:00
# psychopy_events_triggers_WP2_21_KBAT_negative.pkl
# psychopy_events_triggers_WP2_23_WPNI.csv
# pre_assesment
# baseline start time: 2023-10-17 16:12:21.707325+02:00
# baseline stop time: 2023-10-17 16:17:21.707325+02:00
# shimmer_baseline start time: 2023-10-17 16:12:21.710938+02:00
# shimmer_baseline stop time: 2023-10-17 16:17:21.707031+02:00
# task start time: 2023-10-17 16:17:21.944951+02:00
# task stop time: 2023-10-17 16:22:21.944951+02:00
# shimmer_task start time: 2023-10-17 16:17:21.945312+02:00
# shimmer_task stop time: 2023-10-17 16:22:21.941406+02:00
# recovery start time: 2023-10-17 16:22:22.948673+02:00
# recovery stop time: 2023-10-17 16:27:22.948673+02:00
# shimmer_recovery start time: 2023-10-17 16:22:22.949219+02:00
# shimmer_recovery stop time: 2023-10-17 16:27:22.945312+02:00
# psychopy_events_triggers_WP2_23_WPNI_pre_assesment.pkl
# positive
# baseline start time: 2023-10-17 16:28:15.913181+02:00
# baseline stop time: 2023-10-17 16:33:15.913181+02:00
# shimmer_baseline start time: 2023-10-17 16:28:15.914062+02:00
# shimmer_baseline stop time: 2023-10-17 16:33:15.910156+02:00
# task start time: 2023-10-17 16:33:16.264561+02:00
# task stop time: 2023-10-17 16:38:16.264561+02:00
# shimmer_task start time: 2023-10-17 16:33:16.265625+02:00
# shimmer_task stop time: 2023-10-17 16:38:16.261719+02:00
# recovery start time: 2023-10-17 16:38:18.014182+02:00
# recovery stop time: 2023-10-17 16:43:18.014182+02:00
# shimmer_recovery start time: 2023-10-17 16:38:18.015625+02:00
# shimmer_recovery stop time: 2023-10-17 16:43:18.011719+02:00
# psychopy_events_triggers_WP2_23_WPNI_positive.pkl
# negative
# baseline start time: 2023-10-17 16:50:39.678771+02:00
# baseline stop time: 2023-10-17 16:55:39.678771+02:00
# shimmer_baseline start time: 2023-10-17 16:50:39.679688+02:00
# shimmer_baseline stop time: 2023-10-17 16:55:39.675781+02:00
# task start time: 2023-10-17 16:55:40.030698+02:00
# task stop time: 2023-10-17 17:00:40.030698+02:00
# shimmer_task start time: 2023-10-17 16:55:40.031250+02:00
# shimmer_task stop time: 2023-10-17 17:00:40.027344+02:00
# recovery start time: 2023-10-17 17:00:42.664335+02:00
# recovery stop time: 2023-10-17 17:05:42.664335+02:00
# shimmer_recovery start time: 2023-10-17 17:00:42.667969+02:00
# shimmer_recovery stop time: 2023-10-17 17:05:42.664062+02:00
# psychopy_events_triggers_WP2_23_WPNI_negative.pkl

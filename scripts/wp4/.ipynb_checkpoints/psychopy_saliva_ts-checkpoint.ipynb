# %%
# system imports
import os
import sys

# data science
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import seaborn as sns

# signal processing
import scipy
from scipy import signal
from scipy.ndimage import label
from scipy.stats import zscore
from scipy.interpolate import interp1d
from scipy.integrate import trapz


# misc
import warnings

import glob

##
import pytz
import datetime as dt
import math
import seaborn as sns

import pickle


#import seaborn

# %%
#style settings
sns.set(style='whitegrid', rc={'axes.facecolor': 'white'})

#sns.set_style({'font.family':'Arial', 'font.serif':'Times New Roman'})

# %%
def read_manipulate_psychopy(psychopy_path):
    
    psychopy_df = pd.read_csv(psychopy_path)
    col_list = [col for col in psychopy_df.columns if col.endswith('_ts')]
    col_list.insert(0, "Reference_time")
    psychopy_df_selected = psychopy_df[col_list]
    
    return psychopy_df_selected


def get_nonNan_list_psychopy(psychopy_df, col_name):
    
    
    selected_vals=[val for val in psychopy_df[col_name].to_list() if not(math.isnan(val))]
    
    return selected_vals

# %%
def get_offset_timestamp(timestamp, offset_mins):
    
    time_zone = 'Europe/Berlin'
    tz = pytz.timezone(time_zone)
    local_time = dt.datetime.fromtimestamp(timestamp, tz)
    time_change = dt.timedelta(minutes=offset_mins)
    new_time = local_time + time_change
    new_timestamp =  dt.datetime.timestamp(new_time)
    return new_timestamp


def get_time_diff_saliva_ts(timestamp_1, timestamp_2):
    
    time_zone = 'Europe/Berlin'
    tz = pytz.timezone(time_zone)
    local_time_1 = dt.datetime.fromtimestamp(timestamp_1, tz)
    local_time_2 = dt.datetime.fromtimestamp(timestamp_2, tz)
    difference = local_time_2 - local_time_1
    diff_seconds = difference.total_seconds() 
    diff_minutes =diff_seconds/60
    
    return diff_minutes

# %%
data_dir_path = "/media/muhammad/d5e4618d-a960-4f0d-a521-1c804bbebbb4/data_sony_digiRelax/wp3"
#data_dir_path = "D:/Datasets/data_sony_digiRelax/study"
sub_dirs=next(os.walk(data_dir_path))[1]
sub_dirs.sort(reverse=False)

des_path = "/media/muhammad/d5e4618d-a960-4f0d-a521-1c804bbebbb4/data_sony_digiRelax/result_psychopy_extracted_info/saliva_time_mins"

# %%
list_saliva_probe_ts= ["saliva_probe_1_ts", "saliva_probe_2_ts","saliva_probe_3_ts", "saliva_probe_4_ts"]
extracted_info_dict = {}
all_files_list=[]
extracted_info_dict["file_name"]=[]

for sub_dir in sub_dirs:
    
    sub_dir_path= os.path.join(data_dir_path, sub_dir)
    psychopy_file_path = os.path.join(sub_dir_path, "Psychopy_data")
    psychopy_file_path = glob.glob(psychopy_file_path+ "/*.csv")[0]
    
    dir_path, file_name=os.path.split(psychopy_file_path)
    extracted_info_dict["file_name"].append(file_name)
    sub_id=file_name[:-4]
    print(sub_id)
    
    
    psychopy_df = read_manipulate_psychopy(psychopy_file_path)
    
    ind_file_list = []
    for ind, sel_saliva in enumerate(list_saliva_probe_ts):
        
    
        if ind==0:

            prev_saliva=sel_saliva
            prev_saliva_ts = get_nonNan_list_psychopy(psychopy_df, prev_saliva)[0]

        else:
            curr_saliva = sel_saliva
            curr_saliva_ts = get_nonNan_list_psychopy(psychopy_df, curr_saliva)[0]
            time_curr_minus_prev=get_time_diff_saliva_ts(prev_saliva_ts, curr_saliva_ts)
            ind_file_list.append(time_curr_minus_prev)

            #print("Time between:  " + curr_saliva +  " - " + prev_saliva + " = " + str(time_curr_minus_prev) + " mins")
            prev_saliva =curr_saliva
            prev_saliva_ts = curr_saliva_ts
            
            
        
        
    all_files_list.append(ind_file_list)
            
    #print("-----------------------------------------------------------------")
    
    
extracted_info_dict["saliva_probe_2_1"] = []
extracted_info_dict["saliva_probe_3_2"] = []
extracted_info_dict["saliva_probe_4_3"] = []

for sel_file in all_list:
    
    #print(sel_file)
    extracted_info_dict["saliva_probe_2_1"].append(sel_file[0])
    extracted_info_dict["saliva_probe_3_2"].append(sel_file[1])
    extracted_info_dict["saliva_probe_4_3"].append(sel_file[1])
# Out:
# VP004_081123_DigiRelax_Experiment_2023-11-08_10h28.36.317
# VP005_081123_DigiRelax_Experiment_2023-11-08_14h17.35.226
# VP006_091123_DigiRelax_Experiment_2023-11-09_10h17.40.415
# VP007_091123_DigiRelax_Experiment_2023-11-09_14h19.56.411
# VP008_101123_DigiRelax_Experiment_2023-11-10_10h24.14.323
# VP009_101123_DigiRelax_Experiment_2023-11-10_14h16.47.223
# VP010_131123_DigiRelax_Experiment_2023-11-13_09h54.08.913
# VP011_131123_DigiRelax_Experiment_2023-11-13_14h42.51.249
# VP012_141123_DigiRelax_Experiment_2023-11-14_09h47.48.508
# VP013_151123_DigiRelax_Experiment_2023-11-15_09h52.50.734
# VP014_151123_DigiRelax_Experiment_2023-11-15_14h23.06.117
# VP015_161123_DigiRelax_Experiment_2023-11-16_09h47.53.124
# VP016_161123_DigiRelax_Experiment_2023-11-16_14h46.57.355
# VP017_171123_DigiRelax_Experiment_2023-11-17_14h43.13.415
# VP018_201123_DigiRelax_Experiment_2023-11-20_09h51.59.612
# VP019_201123_DigiRelax_Experiment_2023-11-20_14h48.37.367
# VP020_221123_DigiRelax_Experiment_2023-11-22_09h48.04.766
# VP021_221123_DigiRelax_Experiment_2023-11-22_14h43.57.344
# VP022_231123_DigiRelax_Experiment_2023-11-23_09h47.27.026
# VP023_231123_DigiRelax_Experiment_2023-11-23_14h49.16.111
# VP024_241123_DigiRelax_Experiment_2023-11-24_15h57.15.078
# VP025_271123_DigiRelax_Experiment_2023-11-27_09h46.03.287
# VP26_271123_DigiRelax_Experiment_2023-11-27_13h16.52.357
# VP027_271123_DigiRelax_Experiment_2023-11-27_15h58.18.227
# VP028_281123_DigiRelax_Experiment_2023-11-28_13h11.36.660
# VP029_281123_DigiRelax_Experiment_2023-11-28_15h49.00.382
# VP030_291123_DigiRelax_Experiment_2023-11-29_09h54.53.886
# VP031_291123_DigiRelax_Experiment_2023-11-29_14h41.15.470
# VP032_301123_DigiRelax_Experiment_2023-11-30_09h49.51.787
# VP033_301123_DigiRelax_Experiment_2023-11-30_15h44.58.284
# VP034_011223_DigiRelax_Experiment_2023-12-01_14h41.10.723
# VP035_041123_DigiRelax_Experiment_2023-12-04_09h54.08.642
# VP037_051223_DigiRelax_Experiment_2023-12-05_10h01.53.815
# VP038_051223_DigiRelax_Experiment_2023-12-05_15h52.43.156
# VP039_061223_DigiRelax_Experiment_2023-12-06_09h56.18.635
# VP040_061223_DigiRelax_Experiment_2023-12-06_13h18.31.319
# VP041_061223_DigiRelax_Experiment_2023-12-06_15h50.23.237
# VP042_071223_DigiRelax_Experiment_2023-12-07_10h46.20.248
# VP043_071223_DigiRelax_Experiment_2023-12-07_13h24.11.749
# VP044_071223_DigiRelax_Experiment_2023-12-07_15h47.55.663
# VP045_081223_DigiRelax_Experiment_2023-12-08_09h50.13.039
# Vp046_081223_DigiRelax_Experiment_2023-12-08_14h49.59.665
# VP047_111223_DigiRelax_Experiment_2023-12-11_14h40.20.997
# VP048_121223_DigiRelax_Experiment_2023-12-12_09h46.06.539
# VP049_121223_DigiRelax_Experiment_2023-12-12_13h41.48.891
# VP050_131223_DigiRelax_Experiment_2023-12-13_09h49.36.277
# VP051_131223_DigiRelax_Experiment_2023-12-13_13h12.46.570
# VP052_131223_DigiRelax_Experiment_2023-12-13_15h40.02.531
# VP053_141223_DigiRelax_Experiment_2023-12-14_09h43.01.217
# VP054_141223_DigiRelax_Experiment_2023-12-14_13h16.33.883
# VP055_141223_DigiRelax_Experiment_2023-12-14_15h45.35.483
# VP056_151223_DigiRelax_Experiment_2023-12-15_09h45.05.317
# VP057_151223_DigiRelax_Experiment_2023-12-15_15h00.46.722
# VP059_181223_DigiRelax_Experiment_2023-12-18_14h46.34.198
# VP060_191223_DigiRelax_Experiment_2023-12-19_09h48.26.679
# VP063_040124_DigiRelax_Experiment_2024-01-04_14h59.12.423
# VP064_050124_DigiRelax_Experiment_2024-01-05_09h44.11.070
# VP065_050124_DigiRelax_Experiment_2024-01-05_14h41.28.548
# VP066_080124_DigiRelax_Experiment_2024-01-08_13h36.32.476
# VP067_100124_DigiRelax_Experiment_2024-01-10_09h51.01.071
# VP068_100124_DigiRelax_Experiment_2024-01-10_14h41.55.244
# VP069_110124_DigiRelax_Experiment_2024-01-11_09h51.14.639
# VP070_110124_DigiRelax_Experiment_2024-01-11_14h48.50.074
# VP071_120124_DigiRelax_Experiment_2024-01-12_09h48.13.466
# VP072_120124_DigiRelax_Experiment_2024-01-12_14h45.23.547
# VP073_150124_DigiRelax_Experiment_2024-01-15_10h17.11.190
# VP074_170124_DigiRelax_Experiment_2024-01-17_09h52.17.376
# VP075_180124_DigiRelax_Experiment_2024-01-18_09h54.07.734
# VP076_220124_DigiRelax_Experiment_2024-01-22_14h29.54.037
# VP077_240124_DigiRelax_Experiment_2024-01-24_09h41.27.985
# VP078_240124_DigiRelax_Experiment_2024-01-24_14h45.04.447
# VP079_250124_DigiRelax_Experiment_2024-01-25_11h20.02.642
# VP080_250124_DigiRelax_Experiment_2024-01-25_14h58.20.993
# VP081_260124_DigiRelax_Experiment_2024-01-26_10h25.25.740
# VP083_310124_DigiRelax_Experiment_2024-01-31_09h50.52.785
# VP084_310124_DigiRelax_Experiment_2024-01-31_13h14.59.762
# VP085_010224_DigiRelax_Experiment_2024-02-01_09h49.30.242
# VP086_010224_DigiRelax_Experiment_2024-02-01_14h19.56.788

# %%
extracted_info_dict
# Out:
# {'file_name': ['VP004_081123_DigiRelax_Experiment_2023-11-08_10h28.36.317.csv',
#   'VP005_081123_DigiRelax_Experiment_2023-11-08_14h17.35.226.csv',
#   'VP006_091123_DigiRelax_Experiment_2023-11-09_10h17.40.415.csv',
#   'VP007_091123_DigiRelax_Experiment_2023-11-09_14h19.56.411.csv',
#   'VP008_101123_DigiRelax_Experiment_2023-11-10_10h24.14.323.csv',
#   'VP009_101123_DigiRelax_Experiment_2023-11-10_14h16.47.223.csv',
#   'VP010_131123_DigiRelax_Experiment_2023-11-13_09h54.08.913.csv',
#   'VP011_131123_DigiRelax_Experiment_2023-11-13_14h42.51.249.csv',
#   'VP012_141123_DigiRelax_Experiment_2023-11-14_09h47.48.508.csv',
#   'VP013_151123_DigiRelax_Experiment_2023-11-15_09h52.50.734.csv',
#   'VP014_151123_DigiRelax_Experiment_2023-11-15_14h23.06.117.csv',
#   'VP015_161123_DigiRelax_Experiment_2023-11-16_09h47.53.124.csv',
#   'VP016_161123_DigiRelax_Experiment_2023-11-16_14h46.57.355.csv',
#   'VP017_171123_DigiRelax_Experiment_2023-11-17_14h43.13.415.csv',
#   'VP018_201123_DigiRelax_Experiment_2023-11-20_09h51.59.612.csv',
#   'VP019_201123_DigiRelax_Experiment_2023-11-20_14h48.37.367.csv',
#   'VP020_221123_DigiRelax_Experiment_2023-11-22_09h48.04.766.csv',
#   'VP021_221123_DigiRelax_Experiment_2023-11-22_14h43.57.344.csv',
#   'VP022_231123_DigiRelax_Experiment_2023-11-23_09h47.27.026.csv',
#   'VP023_231123_DigiRelax_Experiment_2023-11-23_14h49.16.111.csv',
#   'VP024_241123_DigiRelax_Experiment_2023-11-24_15h57.15.078.csv',
#   'VP025_271123_DigiRelax_Experiment_2023-11-27_09h46.03.287.csv',
#   'VP26_271123_DigiRelax_Experiment_2023-11-27_13h16.52.357.csv',
#   'VP027_271123_DigiRelax_Experiment_2023-11-27_15h58.18.227.csv',
#   'VP028_281123_DigiRelax_Experiment_2023-11-28_13h11.36.660.csv',
#   'VP029_281123_DigiRelax_Experiment_2023-11-28_15h49.00.382.csv',
#   'VP030_291123_DigiRelax_Experiment_2023-11-29_09h54.53.886.csv',
#   'VP031_291123_DigiRelax_Experiment_2023-11-29_14h41.15.470.csv',
#   'VP032_301123_DigiRelax_Experiment_2023-11-30_09h49.51.787.csv',
#   'VP033_301123_DigiRelax_Experiment_2023-11-30_15h44.58.284.csv',
#   'VP034_011223_DigiRelax_Experiment_2023-12-01_14h41.10.723.csv',
#   'VP035_041123_DigiRelax_Experiment_2023-12-04_09h54.08.642.csv',
#   'VP037_051223_DigiRelax_Experiment_2023-12-05_10h01.53.815.csv',
#   'VP038_051223_DigiRelax_Experiment_2023-12-05_15h52.43.156.csv',
#   'VP039_061223_DigiRelax_Experiment_2023-12-06_09h56.18.635.csv',
#   'VP040_061223_DigiRelax_Experiment_2023-12-06_13h18.31.319.csv',
#   'VP041_061223_DigiRelax_Experiment_2023-12-06_15h50.23.237.csv',
#   'VP042_071223_DigiRelax_Experiment_2023-12-07_10h46.20.248.csv',
#   'VP043_071223_DigiRelax_Experiment_2023-12-07_13h24.11.749.csv',
#   'VP044_071223_DigiRelax_Experiment_2023-12-07_15h47.55.663.csv',
#   'VP045_081223_DigiRelax_Experiment_2023-12-08_09h50.13.039.csv',
#   'Vp046_081223_DigiRelax_Experiment_2023-12-08_14h49.59.665.csv',
#   'VP047_111223_DigiRelax_Experiment_2023-12-11_14h40.20.997.csv',
#   'VP048_121223_DigiRelax_Experiment_2023-12-12_09h46.06.539.csv',
#   'VP049_121223_DigiRelax_Experiment_2023-12-12_13h41.48.891.csv',
#   'VP050_131223_DigiRelax_Experiment_2023-12-13_09h49.36.277.csv',
#   'VP051_131223_DigiRelax_Experiment_2023-12-13_13h12.46.570.csv',
#   'VP052_131223_DigiRelax_Experiment_2023-12-13_15h40.02.531.csv',
#   'VP053_141223_DigiRelax_Experiment_2023-12-14_09h43.01.217.csv',
#   'VP054_141223_DigiRelax_Experiment_2023-12-14_13h16.33.883.csv',
#   'VP055_141223_DigiRelax_Experiment_2023-12-14_15h45.35.483.csv',
#   'VP056_151223_DigiRelax_Experiment_2023-12-15_09h45.05.317.csv',
#   'VP057_151223_DigiRelax_Experiment_2023-12-15_15h00.46.722.csv',
#   'VP059_181223_DigiRelax_Experiment_2023-12-18_14h46.34.198.csv',
#   'VP060_191223_DigiRelax_Experiment_2023-12-19_09h48.26.679.csv',
#   'VP063_040124_DigiRelax_Experiment_2024-01-04_14h59.12.423.csv',
#   'VP064_050124_DigiRelax_Experiment_2024-01-05_09h44.11.070.csv',
#   'VP065_050124_DigiRelax_Experiment_2024-01-05_14h41.28.548.csv',
#   'VP066_080124_DigiRelax_Experiment_2024-01-08_13h36.32.476.csv',
#   'VP067_100124_DigiRelax_Experiment_2024-01-10_09h51.01.071.csv',
#   'VP068_100124_DigiRelax_Experiment_2024-01-10_14h41.55.244.csv',
#   'VP069_110124_DigiRelax_Experiment_2024-01-11_09h51.14.639.csv',
#   'VP070_110124_DigiRelax_Experiment_2024-01-11_14h48.50.074.csv',
#   'VP071_120124_DigiRelax_Experiment_2024-01-12_09h48.13.466.csv',
#   'VP072_120124_DigiRelax_Experiment_2024-01-12_14h45.23.547.csv',
#   'VP073_150124_DigiRelax_Experiment_2024-01-15_10h17.11.190.csv',
#   'VP074_170124_DigiRelax_Experiment_2024-01-17_09h52.17.376.csv',
#   'VP075_180124_DigiRelax_Experiment_2024-01-18_09h54.07.734.csv',
#   'VP076_220124_DigiRelax_Experiment_2024-01-22_14h29.54.037.csv',
#   'VP077_240124_DigiRelax_Experiment_2024-01-24_09h41.27.985.csv',
#   'VP078_240124_DigiRelax_Experiment_2024-01-24_14h45.04.447.csv',
#   'VP079_250124_DigiRelax_Experiment_2024-01-25_11h20.02.642.csv',
#   'VP080_250124_DigiRelax_Experiment_2024-01-25_14h58.20.993.csv',
#   'VP081_260124_DigiRelax_Experiment_2024-01-26_10h25.25.740.csv',
#   'VP083_310124_DigiRelax_Experiment_2024-01-31_09h50.52.785.csv',
#   'VP084_310124_DigiRelax_Experiment_2024-01-31_13h14.59.762.csv',
#   'VP085_010224_DigiRelax_Experiment_2024-02-01_09h49.30.242.csv',
#   'VP086_010224_DigiRelax_Experiment_2024-02-01_14h19.56.788.csv'],
#  'saliva_probe_2_1': [],
#  'saliva_probe_3_2': [],
#  'saliva_probe_4_3': []}
